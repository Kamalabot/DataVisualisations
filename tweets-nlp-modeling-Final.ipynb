# %% [markdown]
# <a href="https://www.kaggle.com/kamaljp/tweets-nlp-classification?scriptVersionId=89963613" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ### <a id="cont"> Game Plan
#
# Classifying a bit of sentence can become tedious when done many times.
#
# Computer can recognise the "tedious" word in above sentence, yet have no emotional or even computational response. We are going to try and succeed in creating such a response from the Computer, using the NLP library Spacy and ML libraries in this notebook.
#
# [Is the dataset balanced?](#vis_1)
#
# [Which country or locality has had many tweets?](#vis_2)
#
# [How the sentences are represented in spaCy under the hood?](#vis_dis)
#
# [Which keyword has been used in tweets to communicate the disasters?](#vis_3)
#
# [Which keyword have communicated correctly when a disaster has occured?](#vis_4)
#
# What Next?
#
#     The Roots that are used in the tweets that communicate is identfied. Some of these roots create false positives and some create false negatives. Further analysis and understanding is required. Based on that, predictions will be conducted.
#
# [Keywords alone are insufficient](#kw)
#
# [Seems the regular NER doesn't recognize disasters](#ner)
#
# [What is the matcher predicting?](#mat)
#
# [Evaluating the predictions of matcher](#mat_eval)
#
# [So what Next???](#next)
#
#         The Roots alon are not enough. The entities needs to be recognized and used for classification. NER pip
#
# [Training the New NER in the pipeline](#t_ner)
#
# [Training the text categorizer pipe](#tex)
#
# [Output & Submission](#sub)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import spacy
import plotly.express as px

from spacy import displacy
from spacy.matcher import Matcher

import warnings
warnings.filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nlp-getting-started/sample_submission.csv
# /kaggle/input/nlp-getting-started/train.csv
# /kaggle/input/nlp-getting-started/test.csv

# %%
train = pd.read_csv('/kaggle/input/nlp-getting-started/train.csv')
train.head(2)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
#
#    target
# 0       1
# 1       1

# %%
test = pd.read_csv('/kaggle/input/nlp-getting-started/test.csv')
test.head(2)
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...

# %%
#Loading the spacy library with the small corpus model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ### <a id="vis_1"> Is the dataset balanced?

# %%
#Lets warm up the dataset with some visuals

#Is the training dataset balanced? 

balance = train.groupby('target')['id'].count().reset_index()
balance.head()

balance.target = balance.target.apply(lambda x: str(x))

fig = px.bar(data_frame=balance, x='target',y='id',color='target')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="c7f12e39-032e-42d7-b09b-780e521fb522" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7f12e39-032e-42d7-b09b-780e521fb522")) {                    Plotly.newPlot(                        "c7f12e39-032e-42d7-b09b-780e521fb522",                        [{"alignmentgroup":"True","hovertemplate":"target=%{x}<br>id=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["0"],"xaxis":"x","y":[4342],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"target=%{x}<br>id=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"textposition":"auto","x":["1"],"xaxis":"x","y":[3271],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoord ...

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="vis_2"> Which country or locality has had many tweets?

# %%
lokale = train.groupby('location')['id'].count().reset_index()
lokale.sort_values('id',ascending=False,inplace=True)

fig = px.bar(data_frame=lokale[:50], y='location',x='id',color='location')
fig.update_layout(yaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="0f642dd1-e4b6-490f-a678-2269c4b3265c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f642dd1-e4b6-490f-a678-2269c4b3265c")) {                    Plotly.newPlot(                        "0f642dd1-e4b6-490f-a678-2269c4b3265c",                        [{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"USA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"USA","offsetgroup":"USA","orientation":"h","showlegend":true,"textposition":"auto","x":[104],"xaxis":"x","y":["USA"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"New York","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"New York","offsetgroup":"New York","orientation":"h","showlegend":true,"textposition":"auto","x":[71],"xaxis":"x","y":["New York"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"United States","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"h","showlegend":true,"textposition":"auto","x":[50],"xaxis":"x","y":["United States"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"London","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"London","offsetgroup":"London","orientation":"h","showlegend":true,"textposition":"auto","x":[45],"xaxis":"x","y":["London"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"Canada","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[29],"xaxis":"x","y":["Canada"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"Nigeria","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Nigeria","offsetgroup":"Nigeria","orientation":"h","showlegend":true,"textposition":"auto","x":[28],"xaxis":"x","y":["Nigeria"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"UK","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"UK","offsetgroup":"UK","orientation":"h","showlegend":true,"textposition":"auto","x":[27],"xaxis":"x","y":["UK"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"Los Angeles, CA","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Los Angeles, CA","offsetgroup":"Los Angeles, CA","orientation":"h","showlegend":true,"textposition":"auto","x":[26],"xaxis":"x","y":["Los Angeles, CA"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"India","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[24],"xaxis":"x","y":["India"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"Mumbai","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Mumbai","offsetgroup":"Mumbai","orientation":"h","showlegend":true,"textposition":"auto","x":[22],"xaxis":"x","y":["Mumbai"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"Washington, DC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Washington, DC","offsetgroup":"Washington, DC","orientation":"h","showlegend":tr ...

# %% [markdown]
# [back to top](#cont)

# %%
#Let us sample some tweets
for x in train.text[:10]:
    print(x)
# Out:
# Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# Forest fire near La Ronge Sask. Canada
# All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 13,000 people receive #wildfires evacuation orders in California
# Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
# #RockyFire Update => California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires
# #flood #disaster Heavy rain causes flash flooding of streets in Manitou, Colorado Springs areas
# I'm on top of the hill and I can see a fire in the woods...
# There's an emergency evacuation happening now in the building across the street
# I'm afraid that the tornado is coming to our area...

# %%
#Replacing the %20 with space
train.loc[~train.keyword.isna(),'keyword'] = train.loc[~train.keyword.isna(),'keyword'].apply(lambda x: x.replace('%20',' '))

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="vis_dis"> How the sentences are represented in spaCy under the hood?

# %%
text = nlp(train.text[136])
displacy.render(text.sents, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1d45c3e1173e423dafca8c8b5c988dc3-0" class="displacy" width="3200" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Experts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">France</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">begin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">examining</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">airplane</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">debris</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">found</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Reunion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Island:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">French</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">air</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">accident</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">experts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">o...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">http://t.co/YVVPznZmXg #</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">news</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-0" stroke-width="2px" d="M70,352.0 C70,89.5 570.0,89.5 570.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-1" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,354.0 L218.0,342.0 202.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-2" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,354.0 L393.0,342.0 377.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-4" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d45c3e1173e423dafca8c8b5c988dc3-0-5" stroke-width="2px" d="M770,352.0 C770,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size:

# %% [markdown]
# [back to top](#cont)

# %%
# The keywords can be more informative, so let us use the power of Spacy objects and lemmatize
key = nlp(train.keyword[136])

#Keyword of interest has to be a Root
for token in key:
    print(token.lemma_,token.pos_,token.dep_)
# Out:
# airplane NOUN compound
# accident NOUN ROOT

# %%
keys =(_ for _ in train.loc[~train.keyword.isna(),'keyword'])

# %%
#helper function to return the root keyword as a lemma. That will greatly reduce the different keywords
def get_root(key):
    doc = nlp(key)
    for token in doc:
        if token.dep_ == 'ROOT':
            return token.lemma_

# %%
#creating ROOT column 
train.loc[~train.keyword.isna(),'roots'] = train.loc[~train.keyword.isna(),'keyword'].apply(lambda x: get_root(x))

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="vis_3"> Which keyword has been used in tweets to communicate the disasters?

# %%
key_root = train.groupby('roots')['id'].count().reset_index()
key_root.sort_values('id',ascending=False,inplace=True)

fig = px.bar(data_frame=key_root[:50], y='roots',x='id',color='roots')
fig.update_layout(yaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="e8c2303a-2838-4e9d-9afd-a08d4c99f7d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8c2303a-2838-4e9d-9afd-a08d4c99f7d5")) {                    Plotly.newPlot(                        "e8c2303a-2838-4e9d-9afd-a08d4c99f7d5",                        [{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"fire","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"fire","offsetgroup":"fire","orientation":"h","showlegend":true,"textposition":"auto","x":[145],"xaxis":"x","y":["fire"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"flood","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"flood","offsetgroup":"flood","orientation":"h","showlegend":true,"textposition":"auto","x":[109],"xaxis":"x","y":["flood"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"bomb","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"bomb","offsetgroup":"bomb","orientation":"h","showlegend":true,"textposition":"auto","x":[107],"xaxis":"x","y":["bomb"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"scream","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"scream","offsetgroup":"scream","orientation":"h","showlegend":true,"textposition":"auto","x":[105],"xaxis":"x","y":["scream"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"building","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"building","offsetgroup":"building","orientation":"h","showlegend":true,"textposition":"auto","x":[105],"xaxis":"x","y":["building"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"collapse","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"collapse","offsetgroup":"collapse","orientation":"h","showlegend":true,"textposition":"auto","x":[104],"xaxis":"x","y":["collapse"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"storm","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"storm","offsetgroup":"storm","orientation":"h","showlegend":true,"textposition":"auto","x":[104],"xaxis":"x","y":["storm"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"drown","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"drown","offsetgroup":"drown","orientation":"h","showlegend":true,"textposition":"auto","x":[104],"xaxis":"x","y":["drown"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"disaster","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"disaster","offsetgroup":"disaster","orientation":"h","showlegend":true,"textposition":"auto","x":[103],"xaxis":"x","y":["disaster"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"fatality","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"fatality","offsetgroup":"fatality","orientation":"h","showlegend":true,"textposition":"auto","x":[82],"xaxis":"x","y":["fatality"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"sink","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sink","offsetgroup":"sink","orientation":"h","showlegend":true,"textposition":"auto","x":[80],"xaxis":"x","y":["sink"],"yaxis":"y","type":"bar"},{"alignmen ...

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="vis_4"> Which keyword have communicated correctly when a disaster has occured?

# %%
target_root = train.groupby(['roots','target'])['id'].count().reset_index()
target_root.sort_values('id',ascending=False,inplace=True)
target_root.target = target_root.target.apply(lambda x: str(x))

# %%
fig = px.bar(data_frame=target_root[50:100], y='roots',x='id',color='target')
fig.update_layout(yaxis={'categoryorder':'total descending'},height=1000)
fig.show()
# Out:
# <div>                            <div id="d764df81-6641-400e-8ce2-99c353ba2588" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d764df81-6641-400e-8ce2-99c353ba2588")) {                    Plotly.newPlot(                        "d764df81-6641-400e-8ce2-99c353ba2588",                        [{"alignmentgroup":"True","hovertemplate":"target=1<br>id=%{x}<br>roots=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"h","showlegend":true,"textposition":"auto","x":[37,37,36,36,35,34,33,32,31,31,30,30,29,29,28,28],"xaxis":"x","y":["spill","debris","wound","fatality","death","emergency","crash","rescuer","weapon","raze","earthquake","bomber","wildfire","collision","drought","sandstorm"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"target=0<br>id=%{x}<br>roots=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"h","showlegend":true,"textposition":"auto","x":[36,36,35,35,35,34,34,34,33,33,32,32,32,32,32,31,30,30,30,30,30,29,29,29,29,29,29,29,28,28,28,28,28,28],"xaxis":"x","y":["ruin","storm","fear","rescue","twister","aftershock","crash","wound","traumatise","blizzard","hellfire","upheaval","bloody","curfew","building","smoke","blood","derail","blight","bleed","stretcher","catastrophe","pandemonium","flatten","desolation","lava","army","inundate","bagging","trouble","meltdown","riot","fall","destruction"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444444 ...

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="kw"> Keywords alone are insufficient
#
# Occurance of a keyword in a tweet by itself cannot make the tweet linked with the disaster. Take the example of "Fire". We will see what the spaCy has to offer next...

# %%
# Tweet that is taking about the disaster  
tweet_1 = train.loc[(train.roots == 'fire') & (train.target == 1),'text'].values[1]
tweet_1
# Out:
# '@POTUS Would you please explain what you are going to do about the volcanoes &amp; bush fires spouting all that CO2 into the air?'

# %%
# Tweet that is taking about the disaster  
tweet_3 = train.loc[(train.roots == 'ablaze') & (train.target == 1),'text'].values[2]
tweet_3
# Out:
# 'INEC Office in Abia Set Ablaze - http://t.co/3ImaomknnA'

# %%
# Tweet that is taking about the debate happening between politcians  
tweet_2 = train.loc[(train.roots == 'fire') & (train.target == 0),'text'].values[1]
tweet_2
# Out:
# 'Ted Cruz fires back at Jeb &amp; Bush: \x89ÛÏWe lose because of Republicans like Jeb &amp; Mitt.\x89Û\x9d [Video] -  http://t.co/bFtiaPF35F'

# %%
#There are multiple pipes in the nlp object that evaluates the sentences. Lets take the support of NER
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7f2189f4e7c0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7f2189f4e6e0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7f2189c79850>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7f2189b668c0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7f2189b62820>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7f2189c79f50>)]

# %%
#Lets check what entities the nlp object returns for the tweets.
doc1 = nlp(tweet_1)

for ent in doc1.ents:
    print(ent.text,ent.label_)
print('_______')
for ent in doc1:
    print(ent.text,ent.pos_,ent.dep_)
    
#Seems the bush plants are considered as the person by the small spaCy Corpus.
# Out:
# bush PERSON
# _______
# @POTUS PROPN npadvmod
# Would AUX aux
# you PRON nsubj
# please INTJ intj
# explain VERB ccomp
# what PRON dobj
# you PRON nsubj
# are AUX aux
# going VERB ccomp
# to PART aux
# do VERB xcomp
# about ADP prep
# the DET det
# volcanoes NOUN pobj
# & CCONJ cc
# amp PROPN conj
# ; PUNCT punct
# bush PROPN compound
# fires VERB ROOT
# spouting VERB xcomp
# all PRON dobj
# that PRON nsubj
# CO2 PROPN relcl
# into ADP prep
# the DET det
# air NOUN pobj
# ? PUNCT punct

# %%
#Lets check what entities the nlp object returns for the tweets.
doc2 = nlp(tweet_2)

for ent in doc2.ents:
    print(ent.text,ent.label_)
print('_______')
for ent in doc2:
    print(ent.text,ent.pos_,ent.dep_)

#We can see the 2nd tweet has got more entities.
# Out:
# Ted Cruz PERSON
# Jeb & ORG
# Bush PERSON
# Republicans NORP
# Jeb & ORG
# _______
# Ted PROPN compound
# Cruz PROPN nsubj
# fires VERB ROOT
# back ADV advmod
# at ADP prep
# Jeb PROPN pobj
# & CCONJ cc
# amp PROPN conj
# ; PUNCT punct
# Bush PROPN conj
# : PUNCT punct
# ÛÏWe ADJ amod
# lose NOUN appos
# because SCONJ prep
# of ADP pcomp
# Republicans PROPN pobj
# like ADP prep
# Jeb PROPN pobj
# & CCONJ cc
# amp PROPN conj
# ; PUNCT punct
# Mitt.Û PROPN compound
# [ X punct
# Video X nmod
# ] X dep
# - PUNCT punct
#   SPACE dep
# http://t.co/bFtiaPF35F NUM appos

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="ner"> Seems the regular NER doesn't recognize disasters
#
# The entities listed on the tweets miss the keywords of interest completely. The Parts of speec and the Dependency pipes give some direction.
#
# The word fire in case of disasters or not, it is showing as a "VERB". In both cases dependency wise it is a "ROOT". The POS is not helping in this case.
#
# ### just using a matcher, not NER
#
# Matchers can be created by using the keyword and then use the process Algo guy at Explosion has shared.... Let me first try this...
#
# ### There are items
#
# There are tweets for which there is no clear keyword that indicates whether it is a disaster or not. Can we reliably extract keywords from these tweets?

# %%
#the pattern required is as below...let us try adding one matcher pattern
pattern = [{'LOWER': 'evacuation', 'POS': {'NOT_IN': ['VERB']}}]
type(pattern)
# Out:
# list

# %%
#create patterns using the function, by giving the keywords
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab, validate=True)

matcher.add("evac_ptn", [pattern])

# %%
#Adding all the roots to the matcher

for keyword in train.roots.unique()[1:]:
    pattern = [{'LOWER': keyword, 'POS': {'NOT_IN': ['VERB']}}]
    pattern_name = keyword+'pattern'
    matcher.add(pattern_name,[pattern])

# %%
fire = (_ for _ in train['text'] if 'fire' in _.lower())
#below loop has to be fired in seperate cell for iteration
for i in range(20):
    print(next(fire))
# Out:
# Forest fire near La Ronge Sask. Canada
# 13,000 people receive #wildfires evacuation orders in California
# Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
# #RockyFire Update => California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires
# I'm on top of the hill and I can see a fire in the woods...
# How the West was burned: Thousands of wildfires ablaze in California alone http://t.co/vl5TBR3wbr
# How the West was burned: Thousands of wildfires ablaze in #California alone http://t.co/iCSjGZ9tE1 #climate #energy http://t.co/9FxmN0l0Bd
# @Navista7 Steve these fires out here are something else! California is a tinderbox - and this clown was setting my 'hood ablaze @News24680
# @nxwestmidlands huge fire at Wholesale markets ablaze http://t.co/rwzbFVNXER
# @OnFireAnders I love you bb
# Los Angeles Times: Arson suspect linked to 30 fires caught in Northern ... - http://t.co/xwMs1AWW8m #NewsInTweets http://t.co/TE2YeRugsi
# Arson suspect linked to 30 fires caught in Northern California http://t.co/EJ2GHNAfHY
# RelaxInPR: miprv: RT latimes: Arson suspect linked to 30 fires caught in Northern California http://t.co/ylhAyfaOOu
# Arson suspect linked to 30 fires caught in Northern California http://t.co/wnuqQAtTTP (via @latimes)
# Arson suspect linked to 30 fires caught in Northern California - Los Angeles Times http://t.co/PrRB4fhXtv
# Arson suspect linked to 30 fires caught in Northern California http://t.co/u1fuWrGK5U
# Arson suspect linked to 30 fires caught in Northern California http://t.co/mmGsyAHDzb
# #Arsonist arrested for setting many fires. WATCH tonightÛªs other #headlines: http://t.co/sqgogJ3S5r. #Nightbeat @VeronicaDLCruz #2MinuteMix
# Arsonist Sets NYC Vegetarian Restaurant on Fire: Police #NewYork - http://t.co/Nr7usT3uh8
# Trusting Iran to stop terrorism is like inviting an arsonist to join the fire brigade - Telegraph http://t.co/2Z2HTDjQZD

# %%
titles = (_ for _ in train['text'])

# %%
for i in range(20):
    doc = nlp(next(titles))
    if len(matcher(doc)) == 1:
        print(doc)
# Out:
# Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# Forest fire near La Ronge Sask. Canada
# Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
# #RockyFire Update => California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires
# I'm on top of the hill and I can see a fire in the woods...
# I'm afraid that the tornado is coming to our area...
# Three people died from the heat wave so far
# #Flood in Bago Myanmar #We arrived Bago

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="mat"> What is the matcher predicting?

# %%
#I learnt about the ways to extend the Jupyter Notebook from 
#the https://www.youtube.com/watch?v=4V0JDdohxAk&list=PLBmcuObd5An559HbDr_alBnwVsGq-7uTF&index=3

from IPython.display import HTML as html_print

#Below two functions lights up the parts of the sentence that the matcher is matching.
def style(s, bold=False):
    blob = f"<text>{s}</text>"
    if bold:
        blob = f"<b style='background-color: #fff59d'>{blob}</b>"
    return blob

def html_generator(g, n=10):
    blob = ""
    for i in range(n):
        doc = next(g)

        state = [[t, False] for t in doc]
        for idx, start, end in matcher(doc):
            for i in range(start, end):
                state[i][1] = True
        blob += style(' '.join([style(str(t[0]), bold=t[1]) for t in state]) + '<br>') 
    return blob

# %%
g = (d for d in nlp.pipe(titles) if matcher(d))
html_print(html_generator(g, n=10))
# Out:
# <text><text>@bbcmtd</text> <text>Wholesale</text> <text>Markets</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>http://t.co/lHYXEOHY6C</text><br></text><text><text>#</text> <text>AFRICANBAZE</text> <text>:</text> <text>Breaking</text> <text>news</text> <text>:</text> <text>Nigeria</text> <text>flag</text> <text>set</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>in</text> <text>Aba</text> <text>.</text> <text>http://t.co/2nndBGwyEi</text><br></text><text><text>Crying</text> <text>out</text> <text>for</text> <text>more</text> <text>!</text> <text>Set</text> <text>me</text> <b style='background-color: #fff59d'><text>ablaze</text></b><br></text><text><text>On</text> <text>plus</text> <text>side</text> <text>LOOK</text> <text>AT</text> <text>THE</text> <text>SKY</text> <text>LAST</text> <text>NIGHT</text> <text>IT</text> <text>WAS</text> <b style='background-color: #fff59d'><text>ABLAZE</text></b> <text>http://t.co/qqsmshaJ3N</text><br></text><text><text>@PhDSquares</text> <text>#</text> <text>mufc</text> <text>they</text> <text>'ve</text> <text>built</text> <text>so</text> <text>much</text> <text>hype</text> <text>around</text> <text>new</text> <text>acquisitions</text> <text>but</text> <text>I</text> <text>doubt</text> <text>they</text> <text>will</text> <text>set</text> <text>the</text> <text>EPL</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>this</text> <text>season</text> <text>.</text><br></text><text><text>INEC</text> <text>Office</text> <text>in</text> <text>Abia</text> <text>Set</text> <b style='background-color: #fff59d'><text>Ablaze</text></b> <text>-</text> <text>http://t.co/3ImaomknnA</text><br></text><text><text>Barbados</text> <text>#</text> <text>Bridgetown</text> <text>JAMAICA</text> <text>ÛÒ</text> <text>Two</text> <text>cars</text> <text>set</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>:</text> <text>SANTA</text> <text>CRUZ</text> <text>ÛÓ</text> <text>Head</text> <text>of</text> <text>the</text> <text>St</text> <text>Elizabeth</text> <b style='background-color: #fff59d'><text>Police</text></b> <text>Superintende</text> <text>...</text> <text> </text> <text>http://t.co/wDUEaj8Q4J</text><br></text><text><b style='background-color: #fff59d'><text>Ablaze</text></b> <text>for</text> <text>you</text> <text>Lord</text> <text>:D</text><br></text><text><text>on</text> <text>the</text> <text>outside</text> <text>you</text> <text>'re</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>and</text> <text>alive</text> <text>
# </text> <text>but</text> <text>you</text> <text>'re</text> <b style='background-color: #fff59d'><text>dead</text></b> <text>inside</text><br></text><text><text>Had</text> <text>an</text> <text>awesome</text> <text>time</text> <text>visiting</text> <text>the</text> <text>CFC</text> <text>head</text> <text>office</text> <text>the</text> <text>ancop</text> <text>site</text> <text>and</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>.</text> <text>Thanks</text> <text>to</text> <text>Tita</text> <text>Vida</text> <text>for</text> <text>taking</text> <text>care</text> <text>of</text> <text>us</text> <text>?</text> <text>?</text><br></text>

# %%
train['Pred']= train.text.apply(lambda d: 1 if len(matcher(nlp(d))) > 0 else 0)

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="mat_eval"> Evaluating the predictions of matcher

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import plotly.express as px
import plotly.graph_objects as go

# %%
def plot_confusion_matrix(y_true, y_pred, class_names):
    confusion_ma = confusion_matrix(y_true, y_pred)
    confusion_ma = confusion_ma.astype(int)

    layout = {
        "title": "Confusion Matrix", 
        "xaxis": {"title": "Predicted value"}, 
        "yaxis": {"title": "Real value"}
    }

    fig = go.Figure(data=go.Heatmap(z=confusion_ma,
                                    x=class_names,
                                    y=class_names,
                                    hoverongaps=False),
                    layout=layout)
    fig.show()

# %%
plot_confusion_matrix(train['target'], train['Pred'],['True','False'])
# Out:
# <div>                            <div id="a176104a-2e7a-4b7b-82de-bb8aa4a7afcf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a176104a-2e7a-4b7b-82de-bb8aa4a7afcf")) {                    Plotly.newPlot(                        "a176104a-2e7a-4b7b-82de-bb8aa4a7afcf",                        [{"hoverongaps":false,"x":["True","False"],"y":["True","False"],"z":[[2008,2334],[821,2450]],"type":"heatmap"}],                        {"title":{"text":"Confusion Matrix"},"xaxis":{"title":{"text":"Predicted value"}},"yaxis":{"title":{"text":"Real value"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker" ...
#
# var gd = document.getElementById('a176104a-2e7a-4b7b-82de-bb8aa4a7afcf');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display

# %%
print(classification_report(train['target'], train['Pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.46      0.56      4342
#            1       0.51      0.75      0.61      3271
#
#     accuracy                           0.59      7613
#    macro avg       0.61      0.61      0.58      7613
# weighted avg       0.62      0.59      0.58      7613

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="next"> So what Next???
#
# There seems to more false negatives from matcher. Disasters are not detected as disasters. What could be causing this anamoly? Checking the matcher, we can observe it is not picking many of the disasters tweets as linked to disasters. The words indicating the disaster is not matching... So lets improve by adding additional language detection
#
# The mistakes done by the matcher can be seen highlighted using the html extension of Jupyter. The matcher is not detecting the words, since the matcher chooses only those keywords that are NOT Verbs.

# %%
mistakes = (train.loc[lambda d: d['Pred'] == 1].loc[lambda d: d['target'] == 1]['text'])

html_print(html_generator((nlp(i) for i in mistakes), n=10))
# Out:
# <text><text>Our</text> <text>Deeds</text> <text>are</text> <text>the</text> <text>Reason</text> <text>of</text> <text>this</text> <text>#</text> <b style='background-color: #fff59d'><text>earthquake</text></b> <text>May</text> <text>ALLAH</text> <text>Forgive</text> <text>us</text> <text>all</text><br></text><text><text>Forest</text> <b style='background-color: #fff59d'><text>fire</text></b> <text>near</text> <text>La</text> <text>Ronge</text> <text>Sask</text> <text>.</text> <text>Canada</text><br></text><text><text>All</text> <text>residents</text> <text>asked</text> <text>to</text> <text>'</text> <text>shelter</text> <text>in</text> <text>place</text> <text>'</text> <text>are</text> <text>being</text> <text>notified</text> <text>by</text> <text>officers</text> <text>.</text> <text>No</text> <text>other</text> <b style='background-color: #fff59d'><text>evacuation</text></b> <text>or</text> <text>shelter</text> <text>in</text> <text>place</text> <text>orders</text> <text>are</text> <text>expected</text><br></text><text><text>13,000</text> <text>people</text> <text>receive</text> <text>#</text> <text>wildfires</text> <b style='background-color: #fff59d'><text>evacuation</text></b> <text>orders</text> <text>in</text> <text>California</text><br></text><text><text>Just</text> <text>got</text> <text>sent</text> <text>this</text> <text>photo</text> <text>from</text> <text>Ruby</text> <text>#</text> <text>Alaska</text> <text>as</text> <b style='background-color: #fff59d'><text>smoke</text></b> <text>from</text> <text>#</text> <text>wildfires</text> <text>pours</text> <text>into</text> <text>a</text> <text>school</text><br></text><text><text>#</text> <text>RockyFire</text> <text>Update</text> <text>=</text> <text>></text> <text>California</text> <text>Hwy</text> <text>.</text> <text>20</text> <text>closed</text> <text>in</text> <text>both</text> <text>directions</text> <text>due</text> <text>to</text> <text>Lake</text> <text>County</text> <b style='background-color: #fff59d'><text>fire</text></b> <text>-</text> <text>#</text> <text>CAfire</text> <text>#</text> <text>wildfires</text><br></text><text><text>#</text> <b style='background-color: #fff59d'><text>flood</text></b> <text>#</text> <b style='background-color: #fff59d'><text>disaster</text></b> <text>Heavy</text> <text>rain</text> <text>causes</text> <text>flash</text> <text>flooding</text> <text>of</text> <text>streets</text> <text>in</text> <text>Manitou</text> <text>,</text> <text>Colorado</text> <text>Springs</text> <text>areas</text><br></text><text><text>I</text> <text>'m</text> <text>on</text> <text>top</text> <text>of</text> <text>the</text> <text>hill</text> <text>and</text> <text>I</text> <text>can</text> <text>see</text> <text>a</text> <b style='background-color: #fff59d'><text>fire</text></b> <text>in</text> <text>the</text> <text>woods</text> <text>...</text><br></text><text><text>There</text> <text>'s</text> <text>an</text> <b style='background-color: #fff59d'><text>emergency</text></b> <b style='background-color: #fff59d'><text>evacuation</text></b> <text>happening</text> <text>now</text> <text>in</text> <text>the</text> <b style='background-color: #fff59d'><text>building</text></b> <text>across</text> <text>the</text> <text>street</text><br></text><text><text>I</text> <text>'m</text> <text>afraid</text> <text>that</text> <text>the</text> <b style='background-color: #fff59d'><text>tornado</text></b> <text>is</text> <text>coming</text> <text>to</text> <text>our</text> <text>area</text> <text>...</text><br></text>

# %%
#We can see there is no matches in the tweets, which is predicted as 0
mistakes = (train.loc[lambda d: d['Pred'] == 0].loc[lambda d: d['target'] == 1]['text'])

html_print(html_generator((nlp(i) for i in mistakes), n=10))
# Out:
# <text><text>Haha</text> <text>South</text> <text>Tampa</text> <text>is</text> <text>getting</text> <text>flooded</text> <text>hah-</text> <text>WAIT</text> <text>A</text> <text>SECOND</text> <text>I</text> <text>LIVE</text> <text>IN</text> <text>SOUTH</text> <text>TAMPA</text> <text>WHAT</text> <text>AM</text> <text>I</text> <text>GONNA</text> <text>DO</text> <text>WHAT</text> <text>AM</text> <text>I</text> <text>GONNA</text> <text>DO</text> <text>FVCK</text> <text>#</text> <text>flooding</text><br></text><text><text>#</text> <text>raining</text> <text>#</text> <text>flooding</text> <text>#</text> <text>Florida</text> <text>#</text> <text>TampaBay</text> <text>#</text> <text>Tampa</text> <text>18</text> <text>or</text> <text>19</text> <text>days</text> <text>.</text> <text>I</text> <text>'ve</text> <text>lost</text> <text>count</text><br></text><text><text>#</text> <text>TruckCrash</text> <text>Overturns</text> <text>On</text> <text>#</text> <text>FortWorth</text> <text>Interstate</text> <text>http://t.co/Rs22LJ4qFp</text> <text>Click</text> <text>here</text> <text>if</text> <text>you</text> <text>'ve</text> <text>been</text> <text>in</text> <text>a</text> <text>crash&gt;http://t.co</text> <text>/</text> <text>Ld0unIYw4k</text><br></text><text><text>Annihilated</text> <text>Abs</text> <text>.</text> <text>?</text> <text>?</text> <text>http://t.co/1xPw292tJe</text><br></text><text><text>Cop</text> <text>pulls</text> <text>drunk</text> <text>driver</text> <text>to</text> <text>safety</text> <text>SECONDS</text> <text>before</text> <text>his</text> <text>car</text> <text>is</text> <text>hit</text> <text>by</text> <text>train</text> <text>.</text> <text>http://t.co/tHrhKHOGcUåÊ</text> <text>http://t.co/tZSZmF2qxE</text> <text>via</text> <text>@ViralSpell</text><br></text><text><text>Cop</text> <text>pulls</text> <text>drunk</text> <text>driver</text> <text>to</text> <text>safety</text> <text>SECONDS</text> <text>before</text> <text>his</text> <text>car</text> <text>is</text> <text>hit</text> <text>by</text> <text>train</text> <text>.</text> <text>http://t.co/C0nKGp6w03åÊ</text> <text>http://t.co/IMWmfDJSSn</text> <text>via</text> <text>@ViralSpell</text><br></text><text><text>@violentfeminazi</text> <text>I</text> <text>guess</text> <text>that</text> <text>'s</text> <text>ok</text> <text>for</text> <text>Armenians</text> <text>since</text> <text>we</text> <text>'ve</text> <text>spent</text> <text>most</text> <text>of</text> <text>our</text> <text>history</text> <text>getting</text> <text>annihilated</text><br></text><text><text>70</text> <text>years</text> <text>since</text> <text>we</text> <text>annihilated</text> <text>100000</text> <text>people</text> <text>instantly</text> <text>and</text> <text>became</text> <text>aware</text> <text>that</text> <text>we</text> <text>have</text> <text>the</text> <text>ability</text> <text>to</text> <text>annihilate</text> <text>the</text> <text>whole</text> <text>of</text> <text>humanity</text><br></text><text><text>During</text> <text>the</text> <text>1960s</text> <text>the</text> <text>oryx</text> <text>a</text> <text>symbol</text> <text>of</text> <text>the</text> <text>Arabian</text> <text>Peninsula</text> <text>were</text> <text>annihilated</text> <text>by</text> <text>hunters</text> <text>.</text> <text>
# </text> <text>http://t.co/yangEQBUQW</text> <text>http://t.co/jQ2eH5KGLt</text><br></text><text><text>Ready</text> <text>to</text> <text>get</text> <text>annihilated</text> <text>for</text> <text>the</text> <text>BUCS</text> <text>game</text><br></text>

# %%
#Extracting the words with the hashtag. The matcher has to choose the words following the tage
pattern = [{"TEXT": "#"}, {"IS_ASCII": True}]
matcher = Matcher(nlp.vocab)
matcher.add("hashTag", [pattern])
matches = matcher(doc)

# %%
doc = nlp(train.text[0])
for mid, start, end in matches:
    print(start, end, doc[start:end])

# %%
def parse_train_data(doc):
    detections = [(doc[start:end].start_char, doc[start:end].end_char, 'disaster') for idx, start, end in matcher(doc)]
    return (doc.text, {'entities': detections})

parse_train_data(nlp("I reject the laws of the misguided false prophets imprison nations fueling self annihilation"))
# Out:
# ('I reject the laws of the misguided false prophets imprison nations fueling self annihilation',
#  {'entities': []})

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="t_ner"> Training the New NER in the pipeline

# %%
titles = train.loc[lambda d: d['target'] == 1]['text']

# %%
#creating the training data
TRAIN_DATA = [parse_train_data(d) for d in nlp.pipe(titles) if len(matcher(d)) == 1]
TRAIN_DATA[5:8]
# Out:
# [('Barbados #Bridgetown JAMAICA \x89ÛÒ Two cars set ablaze: SANTA CRUZ \x89ÛÓ Head of the St Elizabeth Police Superintende...  http://t.co/wDUEaj8Q4J',
#   {'entities': [(9, 20, 'disaster')]}),
#  ('Accident on I-24 W #NashvilleTraffic. Traffic moving 8m slower than usual. https://t.co/0GHk693EgJ',
#   {'entities': [(19, 36, 'disaster')]}),
#  ('.@NorwayMFA #Bahrain police had previously died in a road accident they were not killed by explosion https://t.co/gFJfgTodad',
#   {'entities': [(12, 20, 'disaster')]})]

# %%
def create_blank_nlp(train_data):
    nlp = spacy.blank("en")
    ner = nlp.add_pipe('ner')
    #nlp.add_pipe(ner, last=True)
    ner = nlp.get_pipe("ner")
    for _, annotations in train_data:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])
    return nlp

# %%
import random 
import datetime as dt
from spacy.training import Example

nlp = create_blank_nlp(TRAIN_DATA)
optimizer = nlp.begin_training()  
for i in range(20): #The losses come to single digit at this iteration so retaining
    random.shuffle(TRAIN_DATA)
    losses = {}

    for text, annotations in TRAIN_DATA:
        example = Example.from_dict(nlp.make_doc(text), annotations)
        nlp.update([example],sgd=optimizer, losses=losses)
    print(f"Losses at iteration {i} - {dt.datetime.now()}", losses)
# Out:
# [2022-03-13 05:53:04,042] [INFO] Created vocabulary
# [2022-03-13 05:53:04,045] [INFO] Finished initializing nlp object
# Losses at iteration 0 - 2022-03-13 05:53:14.067345 {'ner': 188.5272182110496}
# Losses at iteration 1 - 2022-03-13 05:53:23.876987 {'ner': 4.507919099329292}
# Losses at iteration 2 - 2022-03-13 05:53:33.458791 {'ner': 2.183839125687786}
# Losses at iteration 3 - 2022-03-13 05:53:43.074705 {'ner': 5.2960800635272565e-05}
# Losses at iteration 4 - 2022-03-13 05:53:52.633217 {'ner': 2.4957640966023046e-10}
# Losses at iteration 5 - 2022-03-13 05:54:02.126704 {'ner': 1.4031867391390734e-08}
# Losses at iteration 6 - 2022-03-13 05:54:11.796219 {'ner': 4.615233982733577e-10}
# Losses at iteration 7 - 2022-03-13 05:54:21.471781 {'ner': 1.197597693732191e-10}
# Losses at iteration 8 - 2022-03-13 05:54:31.129150 {'ner': 2.666532935883055e-10}
# Losses at iteration 9 - 2022-03-13 05:54:40.848390 {'ner': 4.775850908621417e-10}
# Losses at iteration 10 - 2022-03-13 05:54:50.351093 {'ner': 2.4646305400963827e-10}
# Losses at iteration 11 - 2022-03-13 05:54:59.895355 {'ner': 1.0683402400195507e-10}
# Losses at iteration 12 - 2022-03-13 05:55:09.478012 {'ner': 5.148339539521563e-11}
# Losses at iteration 13 - 2022-03-13 05:55:19.034171 {'ner': 6.505745976622675e-11}
# Losses at iteration 14 - 2022-03-13 05:55:28.617759 {'ner': 3.9183115258085457e-10}
# Losses at iteration 15 - 2022-03-13 05:55:38.229626 {'ner': 5.929882355608247e-11}
# Losses at iteration 16 - 2022-03-13 05:55:48.014933 {'ner': 1.0446185517650002e-10}
# Losses at iteration 17 - 2022-03-13 05:55:57.695560 {'ner': 1.2734225989481184e-11}
# Losses at iteration 18 - 2022-03-13 05:56:07.369299 {'ner': 5.250521379407764e-11}
# Losses at iteration 19 - 2022-03-13 05:56:17.097767 {'ner': 4.013211076242088e-12}

# %%
doc = nlp("I'm afraid that the tornado is coming to our area...")
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I'm afraid that the tornado is coming to our area...</div></span>

# %%
train['Pred']= train.text.apply(lambda d: 1 if len(matcher(nlp(d))) > 0 else 0)

# %%
#Let us observe how the ner model predicts the disasters in the mistakes done by the matcher 
html_print(html_generator((nlp(i) for i in mistakes), n=21))
# Out:
# <text><text>Haha</text> <text>South</text> <text>Tampa</text> <text>is</text> <text>getting</text> <text>flooded</text> <text>hah-</text> <text>WAIT</text> <text>A</text> <text>SECOND</text> <text>I</text> <text>LIVE</text> <text>IN</text> <text>SOUTH</text> <text>TAMPA</text> <text>WHAT</text> <text>AM</text> <text>I</text> <text>GONNA</text> <text>DO</text> <text>WHAT</text> <text>AM</text> <text>I</text> <text>GONNA</text> <text>DO</text> <text>FVCK</text> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>flooding</text></b><br></text><text><b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>raining</text></b> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>flooding</text></b> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>Florida</text></b> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>TampaBay</text></b> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>Tampa</text></b> <text>18</text> <text>or</text> <text>19</text> <text>days</text> <text>.</text> <text>I</text> <text>'ve</text> <text>lost</text> <text>count</text><br></text><text><b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>TruckCrash</text></b> <text>Overturns</text> <text>On</text> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>FortWorth</text></b> <text>Interstate</text> <text>http://t.co/Rs22LJ4qFp</text> <text>Click</text> <text>here</text> <text>if</text> <text>you</text> <text>'ve</text> <text>been</text> <text>in</text> <text>a</text> <text>crash&gt;http://t.co</text> <text>/</text> <text>Ld0unIYw4k</text><br></text><text><text>Annihilated</text> <text>Abs</text> <text>.</text> <text>?</text> <text>?</text> <text>http://t.co/1xPw292tJe</text><br></text><text><text>Cop</text> <text>pulls</text> <text>drunk</text> <text>driver</text> <text>to</text> <text>safety</text> <text>SECONDS</text> <text>before</text> <text>his</text> <text>car</text> <text>is</text> <text>hit</text> <text>by</text> <text>train</text> <text>.</text> <text>http://t.co/tHrhKHOGcUåÊ</text> <text>http://t.co/tZSZmF2qxE</text> <text>via</text> <text>@ViralSpell</text><br></text><text><text>Cop</text> <text>pulls</text> <text>drunk</text> <text>driver</text> <text>to</text> <text>safety</text> <text>SECONDS</text> <text>before</text> <text>his</text> <text>car</text> <text>is</text> <text>hit</text> <text>by</text> <text>train</text> <text>.</text> <text>http://t.co/C0nKGp6w03åÊ</text> <text>http://t.co/IMWmfDJSSn</text> <text>via</text> <text>@ViralSpell</text><br></text><text><text>@violentfeminazi</text> <text>I</text> <text>guess</text> <text>that</text> <text>'s</text> <text>ok</text> <text>for</text> <text>Armenians</text> <text>since</text> <text>we</text> <text>'ve</text> <text>spent</text> <text>most</text> <text>of</text> <text>our</text> <text>history</text> <text>getting</text> <text>annihilated</text><br></text><text><text>70</text> <text>years</text> <text>since</text> <text>we</text> <text>annihilated</text> <text>100000</text> <text>people</text> <text>instantly</text> <text>and</text> <text>became</text> <text>aware</text> <text>that</text> <text>we</text> <text>have</text> <text>the</text> <text>ability</text> <text>to</text> <text>annihilate</text> <text>the</text> <text>whole</text> <text>of</text> <text>humanity</text><br></text><text><text>During</text> <text>the</text> <text>1960s</text> <text>the</text> <text>oryx</text> <text>a</text> <text>symbol</text> <text>of</text> <text>the</text> <text>Arabian</text> <text>Peninsula</text> <text>were</text> <text>annihilated</text> <text>by</text> <text>hunters</text> <text>.</text> <text>
# </text> <text>http://t.co/yangEQBUQW</text> <text>http://t.co/jQ2eH5KGLt</text><br></text><text><text>Ready</text> <text>to</text> <text>get</text> <text>annihilated</text> <text>for</text> <text>the</text> <text>BUCS</text> <text>game</text><br></text><text><text>@PhilipDuncan</text> <text>@breakfastone</text> <text>People</text> <text>'</text> <text>annihilated</text> <text>by</text> <text>last</text> <text>nights</text> <text>weather</text> <text>'</text> <text>...</text> <text>Really</text> <text>Philip</text> <text>thought</text> <text>you</text> <text>would</text> <text>have</text> <text>forecast</text> <text>that</text> <text>...</text><br></text><text><text>Cop</text> <text>pulls</text> <text>drunk</text> <text>driver</text> <text>to</text> <text>safety</text> <text>SECONDS</text> <text>before</text> <text>his</text> <text>car</text> <text>is</text> <text>hit</text> <text>by</text> <text>train</text> <text>.</text> <text>http://t.co/F1BAkpNyn6åÊ</text> <text>http://t.co/lZXwoAyE4x</text> <text>via</text> <text>@ViralSpell</text><br></text><text><text>@willienelson</text> <text>We</text> <text>need</text> <text>help</text> <text>!</text> <text>Horses</text> <text>will</text> <text>die!Please</text> <text>RT</text> <text>&</text> <text>amp</text> <text>;</text> <text>sign</text> <text>petition!Take</text> <text>a</text> <text>stand</text> <text>&</text> <text>amp</text> <text>;</text> <text>be</text> <text>a</text> <text>voice</text> <text>for</text> <text>them</text> <text>!</text> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>gilbert23</text></b> <text>https://t.co/e8dl1lNCVu</text><br></text><text><b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>PBBan</text></b> <text>(</text> <text>Temporary:300</text> <text>)</text> <text>hyider_ghost2</text> <text>@'aRmageddon</text> <text>|</text> <text>DO</text> <text>NOT</text> <text>KILL</text> <text>|</text> <text>FLAGS</text> <text>ONLY</text> <text>|</text> <text>Fast</text> <text>XP</text> <text>'</text> <text>for</text> <text>Reason</text><br></text><text><text>Paul</text> <text>Craig</text> <text>Roberts</text> <text>ÛÒ</text> <text>Vladimir</text> <text>Putin</text> <text>Issues</text> <text>Major</text> <text>Warning</text> <text>But</text> <text>Is</text> <text>It</text> <text>Too</text> <text>Late</text> <text>To</text> <text>Escape</text> <text>A</text> <text>http://t.co/NVfKzv5FEx</text> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>brics</text></b> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>roberts</text></b> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>russia</text></b><br></text><text><text>Another</text> <text>fake</text> <text>hate</text> <text>crime</text> <text>Lesbians</text> <text>burn</text> <text>their</text> <text>own</text> <text>house</text> <text>down</text> <text>.</text> <text>What</text> <text>else</text> <text>Is</text> <text>new</text> <text>:</text> <text>http://t.co/66oBQmxImb</text><br></text><text><text>Mariah</text> <text>getting</text> <text>thick</text> <text>in</text> <text>the</text> <text>shoulders</text> <text>poor</text> <text>girl</text> <text>.</text><br></text><text><text>Tennessee</text> <text>lesbian</text> <text>couple</text> <text>faked</text> <text>hate</text> <text>crime</text> <text>and</text> <text>destroyed</text> <text>own</text> <text>home</text> <text>with</text> <text>arsonÛ</text> <text>_</text> <text>http://t.co/10mUEY8PXJ</text> <b style='background-color: #fff59d'><text>#</text></b> <b style='background-color: #fff59d'><text>Lesbian</text></b><br></text><text><text>@_301DC</text> <text>@Cloudy_goldrush</text> <text>i</text> <text>hate</text> <text>white</text> <text>people</text> <text>mo</text><br></text><text><text>Israeli</text> <text>helicopters</t ...

# %%
from spacy.training import Example

example = Example.from_dict(nlp.make_doc(text), annotations)
nlp.update([example])
# Out:
# {'ner': 1.0287979242492208e-16}

# %%
#Helper to check whether the tweet has the entity that shows disaster
def has_disas(doc):
    doc = nlp(doc)
    get_ent = []
    for t in doc.ents:
        get_ent.append(t)
    if len(get_ent) >= 1:
        return True
    else:
        return False

# %%
#Lets test with couple of tweets, say 1st 10 training data
train['result'] = train.text.apply(lambda x: has_disas(x))
train
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target roots  Pred  \
# 0     Our Deeds are the Reason of this #earthquake M...       1   NaN     1
# 1                Forest fire near La Ronge Sask. Canada       1   NaN     0
# 2     All residents asked to 'shelter in place' are ...       1   NaN     0
# 3     13,000 people receive #wildfires evacuation or...       1   NaN     1
# 4     Just got sent this photo from Ruby #Alaska as ...       1   NaN     1
# ...                                                 ...     ...   ...   ...
# 7608  Two giant cranes holding a bridge collapse int...       1   NaN     0
# 7609  @aria_ahrary @TheTawniest The out of control w...       1   NaN     0
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1   NaN     0
# 7611  Police investigating after an e-bike collided ...       1   NaN     0
# 7612  The Latest: More Homes Razed by Northern Calif...       1   NaN     0
#
#       result
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
# ...      ...
# 7608   False
# 7609   False
# 7610   False
# 7611   False
# 7612   False
#
# [7613 rows x 8 columns]

# %% [markdown]
# Below classification report is comparing the simple matcher and the NER pipeline output.

# %%
print(classification_report(train['target'], train['result']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.80      0.68      4342
#            1       0.50      0.26      0.34      3271
#
#     accuracy                           0.57      7613
#    macro avg       0.54      0.53      0.51      7613
# weighted avg       0.55      0.57      0.53      7613

# %%
print(classification_report(train['target'], train['Pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.80      0.68      4342
#            1       0.49      0.26      0.34      3271
#
#     accuracy                           0.57      7613
#    macro avg       0.54      0.53      0.51      7613
# weighted avg       0.55      0.57      0.53      7613

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# The new NER has not provided any better output than what the stock NER has. The next is to train the Text Categorizer in Spacy itself.
#
# ### <a id="tex"> Training the text categorizer pipe

# %%
from spacy.pipeline.textcat import DEFAULT_SINGLE_TEXTCAT_MODEL
from spacy.pipeline.textcat_multilabel import DEFAULT_MULTI_TEXTCAT_MODEL
from spacy.training import Example
import random

# %%
#creating the new language pipeline for text categorizer
nlp = spacy.load("en_core_web_sm")
config = {
"threshold": 0.5,
"model": DEFAULT_MULTI_TEXTCAT_MODEL
}
textcat = nlp.add_pipe("textcat_multilabel",config=config)

# %%
train_examples = []

# Out of 7500+ train data, only 75% train data is taken for creating the categorizer
for index, row in train[:5000].iterrows():
    text = row["text"]
    rating = row["target"]
    label = {"POS": True, "NEG": False} if rating == 1 else {"NEG": True, "POS": False}
    train_examples.append(Example.from_dict(nlp.make_doc(text), {"cats": label}))

# %%
textcat.add_label("POS")
textcat.add_label("NEG")
textcat.initialize(lambda: train_examples, nlp=nlp)

# %%
#training the text categorizer on the training dataset
epochs = 5
with nlp.select_pipes(enable="textcat_multilabel"):
    optimizer = nlp.resume_training()
    for i in range(epochs):
        random.shuffle(train_examples)
        for example in train_examples:
            nlp.update([example], sgd=optimizer)

# %%
validation = train[5000:]

# Use the validation tweets and predict the targets and compare the actual values. 
# The helper function takes the tweet and returns the sentiment

def sent_id(tweet):
    doc = nlp(tweet)
    if doc.cats['POS'] > 0.5:
        return 1
    else:
        return 0

# %%
validation['pred'] = validation.text.apply(lambda x: sent_id(x))
validation.head()
# Out:
#         id   keyword location  \
# 5000  7132  military       NY
# 5001  7134  military      302
# 5002  7135  military      NaN
# 5003  7136  military      NaN
# 5004  7137  military      NaN
#
#                                                    text  target     roots  \
# 5000  13 reasons why we love women in the military  ...       0  military
# 5001  13 reasons why we love women in the military  ...       0  military
# 5002  @UniversityofLaw For the people who died in Hu...       1  military
# 5003  Lot of 20 Tom Clancy Military Mystery Novels -...       0  military
# 5004  @CochiseCollege For the people who died in Hum...       1  military
#
#       Pred  result  pred
# 5000     0   False     0
# 5001     0   False     0
# 5002     0   False     1
# 5003     1    True     0
# 5004     0   False     1

# %% [markdown]
# ### <a id="sub"> Output and Submission
#
# How the text categorizer is performing on the validation set?
#
#     Compared to both the simple matcher, and the custom NER the text categorizer has much higher precision, recall and f1-scores.

# %%
print(classification_report(validation['target'], validation['pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.75      1436
#            1       0.70      0.62      0.65      1177
#
#     accuracy                           0.71      2613
#    macro avg       0.71      0.70      0.70      2613
# weighted avg       0.71      0.71      0.71      2613

# %%
plot_confusion_matrix(validation['target'], validation['pred'],['True','False'])
# Out:
# <div>                            <div id="5c1c9f33-af2f-4956-a991-497493747d5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c1c9f33-af2f-4956-a991-497493747d5f")) {                    Plotly.newPlot(                        "5c1c9f33-af2f-4956-a991-497493747d5f",                        [{"hoverongaps":false,"x":["True","False"],"y":["True","False"],"z":[[1124,312],[452,725]],"type":"heatmap"}],                        {"title":{"text":"Confusion Matrix"},"xaxis":{"title":{"text":"Predicted value"}},"yaxis":{"title":{"text":"Real value"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{ ...
#
# var gd = document.getElementById('5c1c9f33-af2f-4956-a991-497493747d5f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;

# %% [markdown]
# [back to top](#cont)

# %%
#Applying the text categorizer to the testing data.
test['pred'] = test.text.apply(lambda x: sent_id(x))
test.head()
# Out:
#    id keyword location                                               text  \
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan
#
#    pred
# 0     1
# 1     1
# 2     0
# 3     1
# 4     1

# %%
#creating the dataframe with id and targets predicted.
my_submission = pd.DataFrame({'id': test.id, 'target': test.pred})
# you could use any filename. We choose submission here
my_submission.to_csv('submission.csv', index=False)

# %%
my_submission.head()
# Out:
#    id  target
# 0   0       1
# 1   2       1
# 2   3       0
# 3   9       1
# 4  11       1
