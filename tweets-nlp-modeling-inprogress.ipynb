# %% [markdown]
# <a href="https://www.kaggle.com/kamaljp/tweets-nlp-modeling-inprogress?scriptVersionId=89513997" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ### <a id="cont"> Game Plan
#
# Classifying a bit of sentence can become tedious when done many times.
#
# Computer can recognise the "tedious" word in above sentence, yet have no emotional or even computational response. We are going to try and succeed in creating such a response from the Computer, using the NLP library Spacy and ML libraries in this notebook.
#
# [Is the dataset balanced?](#vis_1)
#
# [Which country or locality has had many tweets?](#vis_2)
#
# [How the sentences are represented in spaCy under the hood?](#vis_dis)
#
# [Which keyword has been used in tweets to communicate the disasters?](#vis_3)
#
# [Which keyword have communicated correctly when a disaster has occured?](#vis_4)
#
# What Next?
#
#     The Roots that are used in the tweets that communicate is identfied. Some of these roots create false positives and some create false negatives. Further analysis and understanding is required. Based on that, predictions will be conducted.
#
# [Understanding the results](#results)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import spacy
import plotly.express as px

from spacy import displacy
from spacy.matcher import Matcher

import warnings
warnings.filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nlp-getting-started/sample_submission.csv
# /kaggle/input/nlp-getting-started/train.csv
# /kaggle/input/nlp-getting-started/test.csv

# %%
train = pd.read_csv('/kaggle/input/nlp-getting-started/train.csv')
train.head(2)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
#
#    target
# 0       1
# 1       1

# %%
test = pd.read_csv('/kaggle/input/nlp-getting-started/test.csv')
test.head(2)
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...

# %%
#Loading the spacy library with the small corpus model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ### <a id="vis_1"> Is the dataset balanced?

# %%
#Lets warm up the dataset with some visuals

#Is the training dataset balanced? 

balance = train.groupby('target')['id'].count().reset_index()
balance.head()

balance.target = balance.target.apply(lambda x: str(x))

fig = px.bar(data_frame=balance, x='target',y='id',color='target')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6653c731-3ed6-4b76-b2b5-090b1baba34e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6653c731-3ed6-4b76-b2b5-090b1baba34e")) {                    Plotly.newPlot(                        "6653c731-3ed6-4b76-b2b5-090b1baba34e",                        [{"alignmentgroup":"True","hovertemplate":"target=%{x}<br>id=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["0"],"xaxis":"x","y":[4342],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"target=%{x}<br>id=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"textposition":"auto","x":["1"],"xaxis":"x","y":[3271],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoord ...

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="vis_2"> Which country or locality has had many tweets?

# %%
lokale = train.groupby('location')['id'].count().reset_index()
lokale.sort_values('id',ascending=False,inplace=True)

fig = px.bar(data_frame=lokale[:50], y='location',x='id',color='location')
fig.update_layout(yaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="db7ccc01-69bc-464c-b4f7-bbf48f186706" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db7ccc01-69bc-464c-b4f7-bbf48f186706")) {                    Plotly.newPlot(                        "db7ccc01-69bc-464c-b4f7-bbf48f186706",                        [{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"USA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"USA","offsetgroup":"USA","orientation":"h","showlegend":true,"textposition":"auto","x":[104],"xaxis":"x","y":["USA"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"New York","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"New York","offsetgroup":"New York","orientation":"h","showlegend":true,"textposition":"auto","x":[71],"xaxis":"x","y":["New York"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"United States","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"h","showlegend":true,"textposition":"auto","x":[50],"xaxis":"x","y":["United States"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"London","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"London","offsetgroup":"London","orientation":"h","showlegend":true,"textposition":"auto","x":[45],"xaxis":"x","y":["London"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"Canada","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[29],"xaxis":"x","y":["Canada"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"Nigeria","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Nigeria","offsetgroup":"Nigeria","orientation":"h","showlegend":true,"textposition":"auto","x":[28],"xaxis":"x","y":["Nigeria"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"UK","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"UK","offsetgroup":"UK","orientation":"h","showlegend":true,"textposition":"auto","x":[27],"xaxis":"x","y":["UK"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"Los Angeles, CA","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Los Angeles, CA","offsetgroup":"Los Angeles, CA","orientation":"h","showlegend":true,"textposition":"auto","x":[26],"xaxis":"x","y":["Los Angeles, CA"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"India","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[24],"xaxis":"x","y":["India"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"Mumbai","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Mumbai","offsetgroup":"Mumbai","orientation":"h","showlegend":true,"textposition":"auto","x":[22],"xaxis":"x","y":["Mumbai"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=%{y}<br>id=%{x}<extra></extra>","legendgroup":"Washington, DC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Washington, DC","offsetgroup":"Washington, DC","orientation":"h","showlegend":tr ...

# %% [markdown]
# [back to top](#cont)

# %%
#Let us sample some tweets
for x in train.text[:10]:
    print(x)
# Out:
# Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# Forest fire near La Ronge Sask. Canada
# All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 13,000 people receive #wildfires evacuation orders in California
# Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
# #RockyFire Update => California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires
# #flood #disaster Heavy rain causes flash flooding of streets in Manitou, Colorado Springs areas
# I'm on top of the hill and I can see a fire in the woods...
# There's an emergency evacuation happening now in the building across the street
# I'm afraid that the tornado is coming to our area...

# %%
#Replacing the %20 with space
train.loc[~train.keyword.isna(),'keyword'] = train.loc[~train.keyword.isna(),'keyword'].apply(lambda x: x.replace('%20',' '))

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="vis_dis"> How the sentences are represented in spaCy under the hood?

# %%
text = nlp(train.text[136])
displacy.render(text.sents, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="de36d6b20b034809a7d31d49ac77a17f-0" class="displacy" width="3200" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Experts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">France</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">begin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">examining</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">airplane</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">debris</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">found</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Reunion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Island:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">French</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">air</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">accident</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">experts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">o...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">http://t.co/YVVPznZmXg #</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">news</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de36d6b20b034809a7d31d49ac77a17f-0-0" stroke-width="2px" d="M70,352.0 C70,89.5 570.0,89.5 570.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de36d6b20b034809a7d31d49ac77a17f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de36d6b20b034809a7d31d49ac77a17f-0-1" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de36d6b20b034809a7d31d49ac77a17f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,354.0 L218.0,342.0 202.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de36d6b20b034809a7d31d49ac77a17f-0-2" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de36d6b20b034809a7d31d49ac77a17f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,354.0 L393.0,342.0 377.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de36d6b20b034809a7d31d49ac77a17f-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de36d6b20b034809a7d31d49ac77a17f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de36d6b20b034809a7d31d49ac77a17f-0-4" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-de36d6b20b034809a7d31d49ac77a17f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-de36d6b20b034809a7d31d49ac77a17f-0-5" stroke-width="2px" d="M770,352.0 C770,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size:

# %% [markdown]
# [back to top](#cont)

# %%
# The keywords can be more informative, so let us use the power of Spacy objects and lemmatize
key = nlp(train.keyword[136])

#Keyword of interest has to be a Root
for token in key:
    print(token.lemma_,token.pos_,token.dep_)
# Out:
# airplane NOUN compound
# accident NOUN ROOT

# %%
keys =(_ for _ in train.loc[~train.keyword.isna(),'keyword'])

# %%
#Checking how the conditions work. Even though there is more than one token, it returns only the root 
for i in range(20):
    doc = nlp(next(keys))
    print(doc)
    for token in doc:
        if token.dep_ == 'ROOT':
            print(token.lemma_)
# Out:
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze
# ablaze

# %%
#helper function to return the root keyword as a lemma. That will greatly reduce the different keywords
def get_root(key):
    doc = nlp(key)
    for token in doc:
        if token.dep_ == 'ROOT':
            return token.lemma_

# %%
#creating ROOT column 
train.loc[~train.keyword.isna(),'roots'] = train.loc[~train.keyword.isna(),'keyword'].apply(lambda x: get_root(x))

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="vis_3"> Which keyword has been used in tweets to communicate the disasters?

# %%
key_root = train.groupby('roots')['id'].count().reset_index()
key_root.sort_values('id',ascending=False,inplace=True)

fig = px.bar(data_frame=key_root[:50], y='roots',x='id',color='roots')
fig.update_layout(yaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="165cbbb9-e98c-44a8-bc7e-9dbc900a16a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("165cbbb9-e98c-44a8-bc7e-9dbc900a16a7")) {                    Plotly.newPlot(                        "165cbbb9-e98c-44a8-bc7e-9dbc900a16a7",                        [{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"fire","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"fire","offsetgroup":"fire","orientation":"h","showlegend":true,"textposition":"auto","x":[145],"xaxis":"x","y":["fire"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"flood","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"flood","offsetgroup":"flood","orientation":"h","showlegend":true,"textposition":"auto","x":[109],"xaxis":"x","y":["flood"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"bomb","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"bomb","offsetgroup":"bomb","orientation":"h","showlegend":true,"textposition":"auto","x":[107],"xaxis":"x","y":["bomb"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"scream","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"scream","offsetgroup":"scream","orientation":"h","showlegend":true,"textposition":"auto","x":[105],"xaxis":"x","y":["scream"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"building","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"building","offsetgroup":"building","orientation":"h","showlegend":true,"textposition":"auto","x":[105],"xaxis":"x","y":["building"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"collapse","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"collapse","offsetgroup":"collapse","orientation":"h","showlegend":true,"textposition":"auto","x":[104],"xaxis":"x","y":["collapse"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"storm","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"storm","offsetgroup":"storm","orientation":"h","showlegend":true,"textposition":"auto","x":[104],"xaxis":"x","y":["storm"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"drown","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"drown","offsetgroup":"drown","orientation":"h","showlegend":true,"textposition":"auto","x":[104],"xaxis":"x","y":["drown"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"disaster","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"disaster","offsetgroup":"disaster","orientation":"h","showlegend":true,"textposition":"auto","x":[103],"xaxis":"x","y":["disaster"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"fatality","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"fatality","offsetgroup":"fatality","orientation":"h","showlegend":true,"textposition":"auto","x":[82],"xaxis":"x","y":["fatality"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roots=%{y}<br>id=%{x}<extra></extra>","legendgroup":"sink","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sink","offsetgroup":"sink","orientation":"h","showlegend":true,"textposition":"auto","x":[80],"xaxis":"x","y":["sink"],"yaxis":"y","type":"bar"},{"alignmen ...

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### <a id="vis_4"> Which keyword have communicated correctly when a disaster has occured?

# %%
target_root = train.groupby(['roots','target'])['id'].count().reset_index()
target_root.sort_values('id',ascending=False,inplace=True)
target_root.target = target_root.target.apply(lambda x: str(x))

# %%
fig = px.bar(data_frame=target_root[50:100], y='roots',x='id',color='target')
fig.update_layout(yaxis={'categoryorder':'total descending'},height=1000)
fig.show()
# Out:
# <div>                            <div id="5f8b739e-dd01-4a72-a055-8d7ab630c9f0" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f8b739e-dd01-4a72-a055-8d7ab630c9f0")) {                    Plotly.newPlot(                        "5f8b739e-dd01-4a72-a055-8d7ab630c9f0",                        [{"alignmentgroup":"True","hovertemplate":"target=1<br>id=%{x}<br>roots=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"h","showlegend":true,"textposition":"auto","x":[37,37,36,36,35,34,33,32,31,31,30,30,29,29,28,28],"xaxis":"x","y":["spill","debris","wound","fatality","death","emergency","crash","rescuer","weapon","raze","earthquake","bomber","wildfire","collision","drought","sandstorm"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"target=0<br>id=%{x}<br>roots=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"h","showlegend":true,"textposition":"auto","x":[36,36,35,35,35,34,34,34,33,33,32,32,32,32,32,31,30,30,30,30,30,29,29,29,29,29,29,29,28,28,28,28,28,28],"xaxis":"x","y":["ruin","storm","fear","rescue","twister","aftershock","crash","wound","traumatise","blizzard","hellfire","upheaval","bloody","curfew","building","smoke","blood","derail","blight","bleed","stretcher","catastrophe","pandemonium","flatten","desolation","lava","army","inundate","bagging","trouble","meltdown","riot","fall","destruction"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444444 ...

# %% [markdown]
# [back to top](#cont)

# %% [markdown]
# ### Keywords alone are insufficient
#
# Occurance of a keyword in a tweet by itself cannot make the tweet linked with the disaster. Take the example of "Fire". We will see what the spaCy has to offer next...

# %%
# Tweet that is taking about the disaster  
tweet_1 = train.loc[(train.roots == 'fire') & (train.target == 1),'text'].values[1]
tweet_1
# Out:
# '@POTUS Would you please explain what you are going to do about the volcanoes &amp; bush fires spouting all that CO2 into the air?'

# %%
# Tweet that is taking about the disaster  
tweet_3 = train.loc[(train.roots == 'ablaze') & (train.target == 1),'text'].values[2]
tweet_3
# Out:
# 'INEC Office in Abia Set Ablaze - http://t.co/3ImaomknnA'

# %%
# Tweet that is taking about the debate happening between politcians  
tweet_2 = train.loc[(train.roots == 'fire') & (train.target == 0),'text'].values[1]
tweet_2
# Out:
# 'Ted Cruz fires back at Jeb &amp; Bush: \x89ÛÏWe lose because of Republicans like Jeb &amp; Mitt.\x89Û\x9d [Video] -  http://t.co/bFtiaPF35F'

# %%
#There are multiple pipes in the nlp object that evaluates the sentences. Lets take the support of NER
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7fe6b801a050>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7fe6b801a0c0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7fe6b8031550>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7fe6b7f9e780>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7fe6b7f996e0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7fe6b8031c50>)]

# %%
#Lets check what entities the nlp object returns for the tweets.
doc1 = nlp(tweet_1)

for ent in doc1.ents:
    print(ent.text,ent.label_)
print('_______')
for ent in doc1:
    print(ent.text,ent.pos_,ent.dep_)
    
#Seems the bush plants are considered as the person by the small spaCy Corpus.
# Out:
# bush PERSON
# _______
# @POTUS PROPN npadvmod
# Would AUX aux
# you PRON nsubj
# please INTJ intj
# explain VERB ccomp
# what PRON dobj
# you PRON nsubj
# are AUX aux
# going VERB ccomp
# to PART aux
# do VERB xcomp
# about ADP prep
# the DET det
# volcanoes NOUN pobj
# & CCONJ cc
# amp PROPN conj
# ; PUNCT punct
# bush PROPN compound
# fires VERB ROOT
# spouting VERB xcomp
# all PRON dobj
# that PRON nsubj
# CO2 PROPN relcl
# into ADP prep
# the DET det
# air NOUN pobj
# ? PUNCT punct

# %%
#Lets check what entities the nlp object returns for the tweets.
doc2 = nlp(tweet_2)

for ent in doc2.ents:
    print(ent.text,ent.label_)
print('_______')
for ent in doc2:
    print(ent.text,ent.pos_,ent.dep_)

#We can see the 2nd tweet has got more entities.
# Out:
# Ted Cruz PERSON
# Jeb & ORG
# Bush PERSON
# Republicans NORP
# Jeb & ORG
# _______
# Ted PROPN compound
# Cruz PROPN nsubj
# fires VERB ROOT
# back ADV advmod
# at ADP prep
# Jeb PROPN pobj
# & CCONJ cc
# amp PROPN conj
# ; PUNCT punct
# Bush PROPN conj
# : PUNCT punct
# ÛÏWe ADJ amod
# lose NOUN appos
# because SCONJ prep
# of ADP pcomp
# Republicans PROPN pobj
# like ADP prep
# Jeb PROPN pobj
# & CCONJ cc
# amp PROPN conj
# ; PUNCT punct
# Mitt.Û PROPN compound
# [ X punct
# Video X nmod
# ] X dep
# - PUNCT punct
#   SPACE dep
# http://t.co/bFtiaPF35F NUM appos

# %% [markdown]
# ### Seems the regular NER doesn't recognize disasters
#
# The entities listed on the tweets miss the keywords of interest completely. The Parts of speec and the Dependency pipes give some direction.
#
# The word fire is "NOUN" in case of disasters and other case it is a "VERB". In both cases dependency wise it is a "ROOT". That may not help.
#
# ### just using a matcher, not NER
#
# Matchers can be created by using the keyword and then use the process Algo guy at explosion has shared.... Let me first try this...
#
# ### There are items
#
# There are tweets for which there is no clear keyword that indicates whether it is a disaster or not. Can we reliably extract keywords from these tweets?

# %%
#the pattern required is as below...let us try adding one matcher pattern
pattern = [{'LOWER': 'evacuation', 'POS': {'NOT_IN': ['VERB']}}]
type(pattern)
# Out:
# list

# %%
#create patterns using the function, by giving the keywords
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab, validate=True)

matcher.add("evac_ptn", [pattern])

# %%
#Adding all the roots to the matcher

for keyword in train.roots.unique()[1:]:
    pattern = [{'LOWER': keyword, 'POS': {'NOT_IN': ['VERB']}}]
    pattern_name = keyword+'pattern'
    matcher.add(pattern_name,[pattern])

# %%
fire = (_ for _ in train['text'] if 'fire' in _.lower())
#below loop has to be fired in seperate cell for iteration
for i in range(20):
    print(next(fire))

# %%
titles = (_ for _ in train['text'])
# Out:
# Firepower in the lab [electronic resource] : automation in the fight against infectious diseases and bioterrorism /Û_ http://t.co/KvpbybglSR
# Pendleton media office said only fire on base right now is the Horno blaze.
# Property losses from California wildfire nearly double as week-old blaze rages http://t.co/E0UUsnpsq5
# #breaking Firefighters battling blaze at east Cary condo building http://t.co/mIM8hH2ce6
# Property losses from #California wildfire nearly double as week-old blaze rages: The fireÛ_ http://t.co/MsdizftZ2g
# Bright &amp; BLAZING Fireman Birthday Party http://t.co/9rFo9GY3nE #Weddings
# Max blew tf up ! ?????? shots fired ???? #CatfishMTV
# Did anyone else see that fireball falling to earth? Look like a plane blew up.
# BREAKING: Fairfax County firefighter placed on admin leave amid probe into Facebook post about putting police in 'body bags' dept. says.
# UPDATE: Va. firefighter on administrative leave after Facebook post calls for people to put officers in 'body bags.' http://t.co/Mt029QJ4Ig
# Fairfax investigating firefighter over Facebook post saying police should be put in Û÷body bagsÛª - The Washington Post http://t.co/jAxHzjCCd4
# this is about to be a bomb ass firework picture http://t.co/lr4BTvuEoM
# Sioux City Fire Officials Believe Bridge Collapse Lead To Cement Truck Roll Over - Siouxland Matters: Siouxlan... http://t.co/sZTGmbkoHG
# @DougMartin17 Fireman Ed runs into burning buildings while others are running out Doug he deserves your respect??????
# The Rocky Fire burning in northern California is still threatening more than 7000 buildings. It's the largest in the state #9newsmornings
# @joshcorman  #infosec rather you knew it or not your a firefighter  now days  you often  run into burning buildings Deal with it.
# @EPCOTExplorer my jealous tears are burning with the fire of a thousand ransacked buildings. SO AWESOMEEEEEEEE
# Watching Xela firefighters struggle to save burning buildings last night w/ old equipment makes me so grateful for DCFD @ChR3lyc @IAFF36
# Fire hazard associated with installation of non-compliant external cladding on http://t.co/bTPQdehl3p - By @www.cbplawyers
# .@greenbuildermag @NFPA to hold free webinar on #wildfire mitigation 8/19 at 2pm ET. http://t.co/xmsvOHKccP @Firewise @Michele_NFPA

# %%
for i in range(20):
    doc = nlp(next(titles))
    if len(matcher(doc)) == 1:
        print(doc)
# Out:
# Owner of Chicago-Area Gay Bar Admits to Arson Scheme http://t.co/0TSlQjOKvh via @theadvocatemag #LGBT
# @sayn_ae angel or arson
# Mourning notices for stabbing arson victims stir Û÷politics of griefÛª in Israel http://t.co/Q4L7Dg56JM
# Owner of Chicago-Area Gay Bar Admits to Arson Scheme http://t.co/2Y9dnP5vtg via @theadvocatemag #LGBT | https://t.co/6XuL6DCOsh
# Owner of Chicago-Area Gay Bar Admits to Arson Scheme http://t.co/UBFr1URAFc #LGBT | https://t.co/AlnV51d95x
# Mourning notices for stabbing arson victims stir Û÷politics of griefÛª in Israel http://t.co/GbluHRrlto
# Owner of Chicago-Area Gay Bar Admits to Arson Scheme http://t.co/ZPxE3fMYNG #LGBT
# Arson suspect linked to 30 fires caught in Northern California http://t.co/wnuqQAtTTP (via @latimes)
# Arson suspect linked to 30 fires caught in Northern California - Los Angeles Times http://t.co/PrRB4fhXtv
# Arson suspect linked to 30 fires caught in Northern California http://t.co/u1fuWrGK5U
# #NOWPLAYING Arsonist MC -  So Impressed -  @ARSONISTMUSIC http://t.co/1ElreH1jLJ
# Alleged East Bay serial arsonist arrested http://t.co/WR48AQTUm7
# Suspected serial arsonist arrested in Calif. http://t.co/PzotPDGAkI
# Arson suspect linked to 30 fires caught in Northern California http://t.co/mmGsyAHDzb

# %%
doc = nlp(trial.text.values[3])
for match_id, start, end in matcher(doc):
    print(doc[start: end])
# Out:
# evacuation

# %%
from IPython.display import HTML as html_print

def style(s, bold=False):
    blob = f"<text>{s}</text>"
    if bold:
        blob = f"<b style='background-color: #fff59d'>{blob}</b>"
    return blob

def html_generator(g, n=10):
    blob = ""
    for i in range(n):
        doc = next(g)

        state = [[t, False] for t in doc]
        for idx, start, end in matcher(doc):
            for i in range(start, end):
                state[i][1] = True
        blob += style(' '.join([style(str(t[0]), bold=t[1]) for t in state]) + '<br>') 
    return blob

# %%
g = (d for d in nlp.pipe(titles) if matcher(d))
html_print(html_generator(g, n=10))
# Out:
# <text><text>@CalFreedomMom</text> <text>@steph93065</text> <text>not</text> <text>to</text> <text>mention</text> <text>a</text> <text>major</text> <text>contributor</text> <text>to</text> <text>the</text> <b style='background-color: #fff59d'><text>annihilation</text></b> <text>of</text> <text>Israel</text><br></text><text><text>I</text> <text>reject</text> <text>the</text> <text>laws</text> <text>of</text> <text>the</text> <text>misguided</text> <text>false</text> <text>prophets</text> <text>imprison</text> <text>nations</text> <text>fueling</text> <text>self</text> <b style='background-color: #fff59d'><text>annihilation</text></b><br></text><text><text>U.S</text> <text>National</text> <text>Park</text> <text>Services</text> <text>Tonto</text> <text>National</text> <text>Forest</text> <text>:</text> <text>Stop</text> <text>the</text> <b style='background-color: #fff59d'><text>Annihilation</text></b> <text>of</text> <text>the</text> <text>Salt</text> <text>River</text> <text>Wild</text> <text>Horse</text> <text>...</text> <text>https://t.co/MatIJwkzbh</text> <text>via</text> <text>@Change</text><br></text><text><text>The</text> <b style='background-color: #fff59d'><text>annihilation</text></b> <text>of</text> <text>Jeb</text> <text>Christie</text> <text>&</text> <text>amp</text> <text>;</text> <text>Kasich</text> <text>is</text> <text>less</text> <text>than</text> <text>24</text> <text>hours</text> <text>away</text> <text>..</text> <text>
# </text> <text>Please</text> <text>God</text> <text>allow</text> <text>me</text> <text>at</text> <text>least</text> <text>one</text> <text>more</text> <text>full</text> <text>day</text> <text>...</text><br></text><text><text>Stop</text> <text>the</text> <b style='background-color: #fff59d'><text>Annihilation</text></b> <text>of</text> <text>the</text> <text>Salt</text> <text>River</text> <text>Wild</text> <text>Horses</text> <text>!</text> <text>http://t.co/wVobVVtXKg</text> <text>via</text> <text>@Change</text><br></text><text><text>@SonofBaldwin</text> <text>and</text> <text>he</text> <text>'s</text> <text>the</text> <text>current</text> <text>Nova</text> <text>in</text> <text>the</text> <text>bookslast</text> <text>I</text> <text>checked</text> <text>..</text> <text>he</text> <text>was</text> <text>tied</text> <text>into</text> <text>the</text> <text>books</text> <text>in</text> <text>2011</text> <text>after</text> <text>Rider</text> <text>died</text> <text>during</text> <b style='background-color: #fff59d'><text>Annihilation</text></b><br></text><text><text>U.S</text> <text>National</text> <text>Park</text> <text>Services</text> <text>Tonto</text> <text>National</text> <text>Forest</text> <text>:</text> <text>Stop</text> <text>the</text> <b style='background-color: #fff59d'><text>Annihilation</text></b> <text>of</text> <text>the</text> <text>Salt</text> <text>River</text> <text>Wild</text> <text>Horse</text> <text>...</text> <text>https://t.co/x2Wn7O2a3w</text> <text>via</text> <text>@Change</text><br></text><text><text>THANKS</text> <text>!</text> <text>!</text> <text>!</text> <text>!</text> <text>!</text> <text>@COUNT</text> <text>DANTE</text> <text>.</text> <text> </text> <text>:)</text> <text> </text> <text>DO</text> <text>JOIN</text> <text>US</text> <text>BY</text> <text>FOLLOWING</text> <text>THE</text> <text>@ANNIHILATION</text> <b style='background-color: #fff59d'><text>ZONE</text></b> <text>.</text> <text> </text> <text>JOHNNY</text> <text>.</text><br></text><text><text>World</text> <b style='background-color: #fff59d'><text>Annihilation</text></b> <text>vs</text> <text>Self</text> <text>Transformation</text> <text>http://t.co/pyehwodWun</text> <text>Aliens</text> <b style='background-color: #fff59d'><text>Attack</text></b> <text>to</text> <text>Exterminate</text> <text>Humans</text> <text>http://t.co/8jxqL8Cv8Z</text><br></text><text><text>U.S</text> <text>National</text> <text>Park</text> <text>Services</text> <text>Tonto</text> <text>National</text> <text>Forest</text> <text>:</text> <text>Stop</text> <text>the</text> <b style='background-color: #fff59d'><text>Annihilation</text></b> <text>of</text> <text>the</text> <text>Salt</text> <text>River</text> <text>Wild</text> <text>Horse</text> <text>...</text> <text>https://t.co/0fekgyBY5F</text> <text>via</text> <text>@Change</text><br></text>

# %%
train['Pred']= train.text.apply(lambda d: 1 if len(matcher(nlp(d))) > 0 else 0)

# %%
train.sample(10)
# Out:
#         id     keyword                   location  \
# 1419  2047  casualties                everywhere
# 456    659      attack                      Dubai
# 4954  7060    meltdown                        NaN
# 953   1380    body bag                   New York
# 6242  8914   snowstorm                     London
# 2069  2970        dead                    Glasgow
# 4327  6146      hijack                        NaN
# 1638  2366   collapsed                   they/her
# 6121  8737     sinking                     London
# 5007  7141    military  highlands&slands scotland
#
#                                                    text  target      roots  \
# 1419  Revise the Death to America scenario? \n\nWhil...       1   casualty
# 456   @etribune  US Drone attack kills 4-suspected m...       1     attack
# 4954  Looks like it may have been microsofts anti vi...       0   meltdown
# 953   New Ladies Shoulder Tote Handbag Women Cross B...       0        bag
# 6242  Can you list 5 reasons why a London #TubeStrik...       0  snowstorm
# 2069  @soapscoop i need you to confirm that ross is ...       0       dead
# 4327  REVEALED: Everton hijack United bid for 14-yea...       0     hijack
# 1638  + DID YOU SAY TO HIM!!?!?!?!' and phil actuall...       0   collapse
# 6121               Slowly sinking wasting ?? @edsheeran       0       sink
# 5007  Bad News for US: China Russia Bolstering Milit...       0   military
#
#       Pred
# 1419     1
# 456      1
# 4954     1
# 953      1
# 6242     1
# 2069     1
# 4327     1
# 1638     0
# 6121     0
# 5007     1

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

confusion_matrix(train['target'], train['Pred'])
# Out:
# array([[2008, 2334],
#        [ 821, 2450]])

# %%
print(classification_report(train['target'], train['Pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.46      0.56      4342
#            1       0.51      0.75      0.61      3271
#
#     accuracy                           0.59      7613
#    macro avg       0.61      0.61      0.58      7613
# weighted avg       0.62      0.59      0.58      7613

# %% [markdown]
# Where the matchers fail due to in-sufficient capability to see the context surrounding itself...

# %%
mistakes = (train.loc[lambda d: d['Pred'] == 1].loc[lambda d: d['target'] == 0]['text'])

html_print(html_generator((nlp(i) for i in mistakes), n=21))
# Out:
# <text><text>Crying</text> <text>out</text> <text>for</text> <text>more</text> <text>!</text> <text>Set</text> <text>me</text> <b style='background-color: #fff59d'><text>ablaze</text></b><br></text><text><text>On</text> <text>plus</text> <text>side</text> <text>LOOK</text> <text>AT</text> <text>THE</text> <text>SKY</text> <text>LAST</text> <text>NIGHT</text> <text>IT</text> <text>WAS</text> <b style='background-color: #fff59d'><text>ABLAZE</text></b> <text>http://t.co/qqsmshaJ3N</text><br></text><text><text>@PhDSquares</text> <text>#</text> <text>mufc</text> <text>they</text> <text>'ve</text> <text>built</text> <text>so</text> <text>much</text> <text>hype</text> <text>around</text> <text>new</text> <text>acquisitions</text> <text>but</text> <text>I</text> <text>doubt</text> <text>they</text> <text>will</text> <text>set</text> <text>the</text> <text>EPL</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>this</text> <text>season</text> <text>.</text><br></text><text><b style='background-color: #fff59d'><text>Ablaze</text></b> <text>for</text> <text>you</text> <text>Lord</text> <text>:D</text><br></text><text><text>on</text> <text>the</text> <text>outside</text> <text>you</text> <text>'re</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>and</text> <text>alive</text> <text>
# </text> <text>but</text> <text>you</text> <text>'re</text> <b style='background-color: #fff59d'><text>dead</text></b> <text>inside</text><br></text><text><text>Had</text> <text>an</text> <text>awesome</text> <text>time</text> <text>visiting</text> <text>the</text> <text>CFC</text> <text>head</text> <text>office</text> <text>the</text> <text>ancop</text> <text>site</text> <text>and</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>.</text> <text>Thanks</text> <text>to</text> <text>Tita</text> <text>Vida</text> <text>for</text> <text>taking</text> <text>care</text> <text>of</text> <text>us</text> <text>?</text> <text>?</text><br></text><text><text>SOOOO</text> <text>PUMPED</text> <text>FOR</text> <b style='background-color: #fff59d'><text>ABLAZE</text></b> <text>?</text> <text>?</text> <text>?</text> <text>?</text> <text>@southridgelife</text><br></text><text><text>I</text> <text>wanted</text> <text>to</text> <text>set</text> <text>Chicago</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>with</text> <text>my</text> <text>preaching</text> <text>...</text> <text>But</text> <text>not</text> <text>my</text> <text>hotel</text> <text>!</text> <text>http://t.co/o9qknbfOFX</text><br></text><text><text>Building</text> <text>the</text> <text>perfect</text> <text>tracklist</text> <text>to</text> <text>life</text> <text>leave</text> <text>the</text> <text>streets</text> <b style='background-color: #fff59d'><text>ablaze</text></b><br></text><text><text>SANTA</text> <text>CRUZ</text> <text>ÛÓ</text> <text>Head</text> <text>of</text> <text>the</text> <text>St</text> <text>Elizabeth</text> <b style='background-color: #fff59d'><text>Police</text></b> <text>Superintendent</text> <text>Lanford</text> <text>Salmon</text> <text>has</text> <text>r</text> <text>...</text> <text>-</text> <text>http://t.co/vplR5Hka2u</text> <text>http://t.co/SxHW2TNNLf</text><br></text><text><text>Set</text> <text>our</text> <text>hearts</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>and</text> <text>every</text> <text>city</text> <text>was</text> <text>a</text> <text>gift</text> <text>And</text> <text>every</text> <text>skyline</text> <text>was</text> <text>like</text> <text>a</text> <text>kiss</text> <text>upon</text> <text>the</text> <text>lips</text> <text>@Û</text> <text>_</text> <text>https://t.co/cYoMPZ1A0Z</text><br></text><text><text>They</text> <text>sky</text> <text>was</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>tonight</text> <text>in</text> <text>Los</text> <text>Angeles</text> <text>.</text> <text>I</text> <text>'m</text> <text>expecting</text> <text>IG</text> <text>and</text> <text>FB</text> <text>to</text> <text>be</text> <text>filled</text> <text>with</text> <text>sunset</text> <text>shots</text> <text>if</text> <text>I</text> <text>know</text> <text>my</text> <text>peeps</text> <text>!</text> <text>!</text><br></text><text><text>Revel</text> <text>in</text> <text>yours</text> <text>wmv</text> <text>videos</text> <text>by</text> <text>means</text> <text>of</text> <text>mac</text> <text>farewell</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>wmv</text> <text>en</text> <text>route</text> <text>to</text> <text>dvd</text> <text>:</text> <text>GtxRWm</text><br></text><text><text>Progressive</text> <text>greetings</text> <text>!</text> <text>
#
# </text> <text>In</text> <text>about</text> <text>a</text> <text>month</text> <text>students</text> <text>would</text> <text>have</text> <text>set</text> <text>their</text> <text>pens</text> <b style='background-color: #fff59d'><text>ablaze</text></b> <text>in</text> <text>The</text> <text>Torch</text> <text>Publications</text> <text>'</text> <text>...</text> <text>http://t.co/9FxPiXQuJt</text><br></text><text><text>Rene</text> <b style='background-color: #fff59d'><text>Ablaze</text></b> <text>&</text> <text>amp</text> <text>;</text> <text>Jacinta</text> <text>-</text> <text>Secret</text> <text>2k13</text> <text>(</text> <text>Fallen</text> <text>Skies</text> <text>Edit</text> <text>)</text> <text>-</text> <text>Mar</text> <text>30</text> <text>2013</text> <text> </text> <text>https://t.co/7MLMsUzV1Z</text><br></text><text><text>#</text> <text>NowPlaying</text> <text>:</text> <text>Rene</text> <b style='background-color: #fff59d'><text>Ablaze</text></b> <text>&</text> <text>amp</text> <text>;</text> <text>Ian</text> <text>Buff</text> <text>-</text> <text>Magnitude</text> <text>http://t.co/Av2JSjfFtc</text> <text> </text> <text>#</text> <text>EDM</text><br></text><text><text>'</text> <text>I</text> <text>ca</text> <text>n't</text> <text>have</text> <text>kids</text> <text>cuz</text> <text>I</text> <text>got</text> <text>in</text> <text>a</text> <text>bicycle</text> <b style='background-color: #fff59d'><text>accident</text></b> <text>&</text> <text>amp</text> <text>;</text> <text>split</text> <text>my</text> <text>testicles</text> <text>.</text> <text>it</text> <text>'s</text> <text>impossible</text> <text>for</text> <text>me</text> <text>to</text> <text>have</text> <text>kids</text> <text>'</text> <text>MICHAEL</text> <text>YOU</text> <text>ARE</text> <text>THE</text> <text>FATHER</text><br></text><text><text>http://t.co/GKYe6gjTk5</text> <text>Had</text> <text>a</text> <text>#</text> <text>personalinjury</text> <b style='background-color: #fff59d'><text>accident</text></b> <text>this</text> <text>summer</text> <text>?</text> <text>Read</text> <text>our</text> <text>advice</text> <text>&</text> <text>amp</text> <text>;</text> <text>see</text> <text>how</text> <text>a</text> <text>#</text> <text>solicitor</text> <text>can</text> <text>help</text> <text>#</text> <text>OtleyHour</text><br></text><text><text>#</text> <text>stlouis</text> <text>#</text> <text>caraccidentlawyer</text> <text>Speeding</text> <text>Among</text> <text>Top</text> <text>Causes</text> <text>of</text> <text>Teen</text> <text>Accidents</text> <text>https://t.co/k4zoMOF319</text> <text>https://t.co/S2kXVM0cBA</text> <text>Car</text> <b style='background-color: #fff59d'><text>Accident</text></b> <text>teeÛ</text> <text>_</text><br></text><text><text>RT</text> <text>@SleepJunkies</text> <text>:</text> <text>Sleeping</text> <text>pills</text> <text>double</text> <text>your</text> <text>risk</text> <text>of</text> <text>a</text> <text>car</text> <b style='background-color: #fff59d'><text>accident</text></b> <text>http://t.co/7s9Nm1fiCT</text><br></text><text><text>'</text> <text>By</text> <b style='background-color: #fff59d'><text>accident</text></b> <text>'</text> <text>they</text> <text>knew</text> <text>what</text> <text>was</text

# %%
def parse_train_data(doc):
    detections = [(doc[start:end].start_char, doc[start:end].end_char, 'disaster') for idx, start, end in matcher(doc)]
    return (doc.text, {'entities': detections})

parse_train_data(nlp("I reject the laws of the misguided false prophets imprison nations fueling self annihilation"))
# Out:
# ('I reject the laws of the misguided false prophets imprison nations fueling self annihilation',
#  {'entities': [(80, 92, 'disaster')]})

# %%
titles = train.loc[lambda d: d['target'] == 1]['text']

# %%
TRAIN_DATA = [parse_train_data(d) for d in nlp.pipe(titles) if len(matcher(d)) == 1]
TRAIN_DATA[5:8]
# Out:
# [("I'm afraid that the tornado is coming to our area...",
#   {'entities': [(20, 27, 'disaster')]}),
#  ('Three people died from the heat wave so far',
#   {'entities': [(32, 36, 'disaster')]}),
#  ('#Flood in Bago Myanmar #We arrived Bago',
#   {'entities': [(1, 6, 'disaster')]})]

# %%
def create_blank_nlp(train_data):
    nlp = spacy.blank("en")
    ner = nlp.add_pipe('ner')
    #nlp.add_pipe(ner, last=True)
    ner = nlp.get_pipe("ner")
    for _, annotations in train_data:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])
    return nlp

# %%
import random 
import datetime as dt
from spacy.training import Example

nlp = create_blank_nlp(TRAIN_DATA)
optimizer = nlp.begin_training()  
for i in range(20):
    random.shuffle(TRAIN_DATA)
    losses = {}

    for text, annotations in TRAIN_DATA:
        example = Example.from_dict(nlp.make_doc(text), annotations)
        nlp.update([example],sgd=optimizer, losses=losses)
    print(f"Losses at iteration {i} - {dt.datetime.now()}", losses)
# Out:
# [2022-03-07 17:03:34,348] [INFO] Created vocabulary
# [2022-03-07 17:03:34,350] [INFO] Finished initializing nlp object
# Losses at iteration 0 - 2022-03-07 17:04:17.100922 {'ner': 861.3638633155387}
# Losses at iteration 1 - 2022-03-07 17:04:59.927589 {'ner': 188.63013989661005}
# Losses at iteration 2 - 2022-03-07 17:05:42.660240 {'ner': 131.66502047391944}
# Losses at iteration 3 - 2022-03-07 17:06:25.026587 {'ner': 103.40991975643412}
# Losses at iteration 4 - 2022-03-07 17:07:09.552182 {'ner': 56.52443143554058}
# Losses at iteration 5 - 2022-03-07 17:07:52.580180 {'ner': 57.53847143672265}
# Losses at iteration 6 - 2022-03-07 17:08:35.675021 {'ner': 46.48526435953866}
# Losses at iteration 7 - 2022-03-07 17:09:19.976954 {'ner': 26.81664975024509}
# Losses at iteration 8 - 2022-03-07 17:10:04.820803 {'ner': 36.12966553141808}
# Losses at iteration 9 - 2022-03-07 17:10:49.844561 {'ner': 17.119364959954122}
# Losses at iteration 10 - 2022-03-07 17:11:35.048594 {'ner': 15.46713665395352}
# Losses at iteration 11 - 2022-03-07 17:12:24.269949 {'ner': 16.763683699683796}
# Losses at iteration 12 - 2022-03-07 17:13:11.637378 {'ner': 34.639390700716866}
# Losses at iteration 13 - 2022-03-07 17:13:56.949892 {'ner': 26.40546061983887}
# Losses at iteration 14 - 2022-03-07 17:14:43.265619 {'ner': 17.03392656891767}
# Losses at iteration 15 - 2022-03-07 17:15:30.862794 {'ner': 9.91169396835061}
# Losses at iteration 16 - 2022-03-07 17:16:23.813240 {'ner': 1.850910752706586e-05}
# Losses at iteration 17 - 2022-03-07 17:17:26.421178 {'ner': 20.83705323932745}
# Losses at iteration 18 - 2022-03-07 17:18:25.172353 {'ner': 30.5652209889319}
# Losses at iteration 19 - 2022-03-07 17:19:13.702802 {'ner': 16.977857218734822}

# %%
nlp.pipeline
# Out:
# [('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7fe6b115ae50>)]

# %%
doc = nlp("I'm afraid that the tornado is coming to our area...")
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I'm afraid that the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tornado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disaster</span>
# </mark>
#  is coming to our area...</div></span>

# %%
from spacy.training import Example

example = Example.from_dict(nlp.make_doc(text), annotations)
nlp.update([example])

# %%
def has_dis_token(doc):
    doc = nlp(doc)
    for t in doc:
        if t.lower_ in train.keyword:
            print(t)
            if t.pos_ == 'NOUN':
                return True
    #if the sentence has got no token that is noun and matching the keyword, then it is a general tweet
    return False

# %%
#Lets test with couple of tweets, say 1st 10 training data
trial = train.iloc[:10,:]
trial['result'] = trial.text.apply(lambda x: has_dis_token(x))
trial
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
# 5   8     NaN      NaN  #RockyFire Update => California Hwy. 20 closed...
# 6  10     NaN      NaN  #flood #disaster Heavy rain causes flash flood...
# 7  13     NaN      NaN  I'm on top of the hill and I can see a fire in...
# 8  14     NaN      NaN  There's an emergency evacuation happening now ...
# 9  15     NaN      NaN  I'm afraid that the tornado is coming to our a...
#
#    target roots  result
# 0       1   NaN   False
# 1       1   NaN   False
# 2       1   NaN   False
# 3       1   NaN   False
# 4       1   NaN   False
# 5       1   NaN   False
# 6       1   NaN   False
# 7       1   NaN   False
# 8       1   NaN   False
# 9       1   NaN   False

# %%
trial.text.values
# Out:
# array(['Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all',
#        'Forest fire near La Ronge Sask. Canada',
#        "All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected",
#        '13,000 people receive #wildfires evacuation orders in California ',
#        'Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school ',
#        '#RockyFire Update => California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires',
#        '#flood #disaster Heavy rain causes flash flooding of streets in Manitou, Colorado Springs areas',
#        "I'm on top of the hill and I can see a fire in the woods...",
#        "There's an emergency evacuation happening now in the building across the street",
#        "I'm afraid that the tornado is coming to our area..."],
#       dtype=object)

# %%
def get_parts(doc):
    tec=[]
    for t in doc:
        tec.append((t.text,t.pos_,t.dep_))
        
    return tec

# %%
#Let us take these tweets and try to see if there is any pattern that we can use
[get_parts(d) for d in nlp.pipe(trial.text)]
# Out:
# [[('Our', 'PRON', 'poss'),
#   ('Deeds', 'NOUN', 'nsubj'),
#   ('are', 'AUX', 'ROOT'),
#   ('the', 'DET', 'det'),
#   ('Reason', 'PROPN', 'attr'),
#   ('of', 'ADP', 'prep'),
#   ('this', 'DET', 'det'),
#   ('#', 'NOUN', 'compound'),
#   ('earthquake', 'NOUN', 'pobj'),
#   ('May', 'AUX', 'aux'),
#   ('ALLAH', 'PROPN', 'nsubj'),
#   ('Forgive', 'VERB', 'advcl'),
#   ('us', 'PRON', 'dobj'),
#   ('all', 'PRON', 'appos')],
#  [('Forest', 'NOUN', 'compound'),
#   ('fire', 'NOUN', 'ROOT'),
#   ('near', 'ADP', 'prep'),
#   ('La', 'PROPN', 'compound'),
#   ('Ronge', 'PROPN', 'compound'),
#   ('Sask', 'PROPN', 'pobj'),
#   ('.', 'PUNCT', 'punct'),
#   ('Canada', 'PROPN', 'ROOT')],
#  [('All', 'DET', 'det'),
#   ('residents', 'NOUN', 'nsubj'),
#   ('asked', 'VERB', 'ROOT'),
#   ('to', 'ADP', 'prep'),
#   ("'", 'PUNCT', 'punct'),
#   ('shelter', 'NOUN', 'pobj'),
#   ('in', 'ADP', 'prep'),
#   ('place', 'NOUN', 'pobj'),
#   ("'", 'PUNCT', 'punct'),
#   ('are', 'AUX', 'aux'),
#   ('being', 'AUX', 'auxpass'),
#   ('notified', 'VERB', 'xcomp'),
#   ('by', 'ADP', 'agent'),
#   ('officers', 'NOUN', 'pobj'),
#   ('.', 'PUNCT', 'punct'),
#   ('No', 'DET', 'det'),
#   ('other', 'ADJ', 'amod'),
#   ('evacuation', 'NOUN', 'nsubjpass'),
#   ('or', 'CCONJ', 'cc'),
#   ('shelter', 'NOUN', 'conj'),
#   ('in', 'ADP', 'prep'),
#   ('place', 'NOUN', 'compound'),
#   ('orders', 'NOUN', 'pobj'),
#   ('are', 'AUX', 'auxpass'),
#   ('expected', 'VERB', 'ROOT')],
#  [('13,000', 'NUM', 'nummod'),
#   ('people', 'NOUN', 'nsubj'),
#   ('receive', 'VERB', 'ROOT'),
#   ('#', 'SYM', 'advmod'),
#   ('wildfires', 'NOUN', 'amod'),
#   ('evacuation', 'NOUN', 'compound'),
#   ('orders', 'NOUN', 'dobj'),
#   ('in', 'ADP', 'prep'),
#   ('California', 'PROPN', 'pobj')],
#  [('Just', 'ADV', 'advmod'),
#   ('got', 'AUX', 'auxpass'),
#   ('sent', 'VERB', 'ROOT'),
#   ('this', 'DET', 'det'),
#   ('photo', 'NOUN', 'dobj'),
#   ('from', 'ADP', 'prep'),
#   ('Ruby', 'PROPN', 'compound'),
#   ('#', 'X', 'compound'),
#   ('Alaska', 'PROPN', 'pobj'),
#   ('as', 'ADP', 'prep'),
#   ('smoke', 'NOUN', 'pobj'),
#   ('from', 'ADP', 'prep'),
#   ('#', 'NOUN', 'pobj'),
#   ('wildfires', 'NOUN', 'advcl'),
#   ('pours', 'NOUN', 'dobj'),
#   ('into', 'ADP', 'prep'),
#   ('a', 'DET', 'det'),
#   ('school', 'NOUN', 'pobj')],
#  [('#', 'SYM', 'nmod'),
#   ('RockyFire', 'PROPN', 'compound'),
#   ('Update', 'PROPN', 'nsubj'),
#   ('=', 'PRON', 'punct'),
#   ('>', 'PUNCT', 'punct'),
#   ('California', 'PROPN', 'compound'),
#   ('Hwy', 'PROPN', 'appos'),
#   ('.', 'PROPN', 'punct'),
#   ('20', 'NUM', 'nsubj'),
#   ('closed', 'VERB', 'ROOT'),
#   ('in', 'ADP', 'prep'),
#   ('both', 'DET', 'det'),
#   ('directions', 'NOUN', 'pobj'),
#   ('due', 'ADP', 'prep'),
#   ('to', 'ADP', 'pcomp'),
#   ('Lake', 'PROPN', 'compound'),
#   ('County', 'PROPN', 'pobj'),
#   ('fire', 'NOUN', 'pobj'),
#   ('-', 'PUNCT', 'punct'),
#   ('#', 'NOUN', 'prep'),
#   ('CAfire', 'PROPN', 'pobj'),
#   ('#', 'NOUN', 'nsubj'),
#   ('wildfires', 'VERB', 'conj')],
#  [('#', 'SYM', 'nmod'),
#   ('flood', 'NOUN', 'nmod'),
#   ('#', 'ADP', 'prep'),
#   ('disaster', 'NOUN', 'pobj'),
#   ('Heavy', 'ADJ', 'amod'),
#   ('rain', 'NOUN', 'nsubj'),
#   ('causes', 'VERB', 'ccomp'),
#   ('flash', 'NOUN', 'compound'),
#   ('flooding', 'NOUN', 'dobj'),
#   ('of', 'ADP', 'prep'),
#   ('streets', 'NOUN', 'pobj'),
#   ('in', 'ADP', 'prep'),
#   ('Manitou', 'PROPN', 'pobj'),
#   (',', 'PUNCT', 'punct'),
#   ('Colorado', 'PROPN', 'compound'),
#   ('Springs', 'PROPN', 'compound'),
#   ('areas', 'NOUN', 'ROOT')],
#  [('I', 'PRON', 'nsubj'),
#   ("'m", 'AUX', 'ROOT'),
#   ('on', 'ADP', 'prep'),
#   ('top', 'NOUN', 'pobj'),
#   ('of', 'ADP', 'prep'),
#   ('the', 'DET', 'det'),
#   ('hill', 'NOUN', 'pobj'),
#   ('and', 'CCONJ', 'cc'),
#   ('I', 'PRON', 'nsubj'),
#   ('can', 'AUX', 'aux'),
#   ('see', 'VERB', 'conj'),
#   ('a', 'DET', 'det'),
#   ('fire', 'NOUN', 'dobj'),
#   ('in', 'ADP', 'prep'),
#   ('the', 'DET', 'det'),
#   ('woods', 'NOUN', 'pobj'),
#   ('...', 'PUNCT', 'punct')],
#  [('There', 'PRON', 'expl'),
#   ("'s", 'VERB', 'ROOT'),
#   ('an', 'DET', 'det'),
#   ('emergency', 'NOUN', 'compound'),
#   ('evacuation', 'NOUN', 'attr'),
#   ('happening', 'VERB', 'acl'),
#   ('now', 'ADV', 'advmod'),
#   ('in', 'ADP', 'prep'),
#   ('the', 'DET', 'det'),
#   ('building', 'NOUN', 'pobj'),
#   ('across', 'ADP', 'prep'),
#   ('the', 'DET', 'det'),
#   ('street', 'NOUN', 'pobj')],
#  [('I', 'PRON', 'nsubj'),
#   ("'m", 'AUX', 'ROOT'),
#   ('afraid', 'ADJ', 'acomp'),
#   ('that', 'SCONJ', 'mark'),
#   ('the', 'DET', 'det'),
#   ('tornado', 'NOUN', 'nsubj'),
#   ('is', 'AUX', 'aux'),
#   ('coming', 'VERB', 'ccomp'),
#   ('to', 'ADP', 'prep'),
#   ('our', 'PRON', 'poss'),
#   ('area', 'NOUN', 'pobj'),
#   ('...', 'PUNCT', 'punct')]]
